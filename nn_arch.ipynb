# %%
import pandas as pd
import numpy as np
from loaders import *
from energy_helpers import get_energy
import torch
import torch.nn as nn

# %%
class HamidaEtAl(nn.Module):
    """
    3-D Deep Learning Approach for Remote Sensing Image Classification
    Amina Ben Hamida, Alexandre Benoit, Patrick Lambert, Chokri Ben Amar
    IEEE TGRS, 2018
    https://ieeexplore.ieee.org/stamp/stamp.jsp?arnumber=8344565
    """
    @staticmethod
    def weight_init(m):
        if isinstance(m, nn.Linear) or isinstance(m, nn.Conv3d):
            init.kaiming_normal_(m.weight)
            init.zeros_(m.bias)

    def __init__(self, input_channels, n_classes, patch_size=5, dilation=1):
        super(HamidaEtAl, self).__init__()
        # The first layer is a (3,3,3) kernel sized Conv characterized
        # by a stride equal to 1 and number of neurons equal to 20
        self.patch_size = patch_size
        self.input_channels = input_channels
        dilation = (dilation, 1, 1)

        if patch_size == 3:
            self.conv1 = nn.Conv3d(
                1, 20, (3, 3, 3), stride=(1, 1, 1), dilation=dilation, padding=1)
        else:
            self.conv1 = nn.Conv3d(
                1, 20, (3, 3, 3), stride=(1, 1, 1), dilation=dilation, padding=0)
        # Next pooling is applied using a layer identical to the previous one
        # with the difference of a 1D kernel size (1,1,3) and a larger stride
        # equal to 2 in order to reduce the spectral dimension
        self.pool1 = nn.Conv3d(
            20, 20, (3, 1, 1), dilation=dilation, stride=(2, 1, 1), padding=(1, 0, 0))
        # Then, a duplicate of the first and second layers is created with
        # 35 hidden neurons per layer.
        self.conv2 = nn.Conv3d(
            20, 75, (3, 3, 3), dilation=dilation, stride=(1, 1, 1), padding=(1, 0, 0))
        self.pool2 = nn.Conv3d(
            75, 75, (3, 1, 1), dilation=dilation, stride=(2, 1, 1), padding=(1, 0, 0))
        # Finally, the 1D spatial dimension is progressively reduced
        # thanks to the use of two Conv layers, 35 neurons each,
        # with respective kernel sizes of (1,1,3) and (1,1,2) and strides
        # respectively equal to (1,1,1) and (1,1,2)
        self.conv3 = nn.Conv3d(
            75, 75, (3, 1, 1), dilation=dilation, stride=(1, 1, 1), padding=(1, 0, 0))
        self.conv4 = nn.Conv3d(
            75, 75, (2, 1, 1), dilation=dilation, stride=(2, 1, 1), padding=(1, 0, 0))

        #self.dropout = nn.Dropout(p=0.5)

        self.features_size = self._get_final_flattened_size()
        # The architecture ends with a fully connected layer where the number
        # of neurons is equal to the number of input classes.
        self.fc = nn.Linear(self.features_size, n_classes)

        # self.apply(self.weight_init)

    def _get_final_flattened_size(self):
        with torch.no_grad():
            x = torch.zeros((1, 1, self.input_channels,
                             self.patch_size, self.patch_size))
            x = self.pool1(self.conv1(x))
            x = self.pool2(self.conv2(x))
            x = self.conv3(x)
            x = self.conv4(x)
            _, t, c, w, h = x.size()
        return t * c * w * h

    def forward(self, x):

        x = F.relu(self.conv1(x))
        x = self.pool1(x)
        x = F.relu(self.conv2(x))
        x = self.pool2(x)
        x = F.relu(self.conv3(x))
        x = F.relu(self.conv4(x))
        x = x.view(-1, self.features_size)
        #x = self.dropout(x)
        x = self.fc(x)
        return x

# %%
# Hamida 3D
model = HamidaEtAl(input_channels=220, n_classes=16)
x = torch.rand(16, 1, 220, 5, 5)

types, energy, l_energy, mac, l_mac, param, l_param, cycle, l_cycle = get_energy(model, x, verbose=False)
print("layer types:", types)
print("energy:", energy, f"(layerwise: {l_energy})")
print("mac:", mac, f"(layerwise: {l_mac})")
print("param:", param, f"(layerwise: {l_param})")
print("cycle:", cycle, f"(layerwise: {l_cycle})")
# Out:
# HERE: designs/system_manual/arch/system_arch_1x16.yaml designs/system_manual/arch/components _layers/layer_shape_0.yaml _layers/map_0.yaml designs/system_auto/mapper/mapper.yaml
# input file: tmp.yaml
#   _______                __
#  /_  __(_)___ ___  ___  / /___  ____  ____
#   / / / / __ `__ \/ _ \/ / __ \/ __ \/ __ \
#  / / / / / / / / /  __/ / /_/ / /_/ / /_/ /
# /_/ /_/_/ /_/ /_/\___/_/\____/\____/ .___/
#                                   /_/
#
# Problem configuration complete.
# Warning: neither block size nor cluster size specified, set according to specified storage width: block size: 1  cluster-size: 1
# Warning: neither block size nor cluster size specified, set according to specified storage width: block size: 1  cluster-size: 1
# Warning: neither block size nor cluster size specified, set according to specified storage width: block size: 1  cluster-size: 1
# Warning: neither block size nor cluster size specified, set according to specified storage width: block size: 1  cluster-size: 1
# Warning: neither block size nor cluster size specified, set according to specified storage width: block size: 1  cluster-size: 1
# execute:/usr/local/bin/accelergy tmp.yaml --oprefix timeloop-mapper. -o ./ > timeloop-mapper.accelergy.log 2>&1
# Generate Accelergy ERT (energy reference table) to replace internal energy model.
# Generate Accelergy ART (area reference table) to replace internal area model.
# Architecture configuration complete.
# Sparse optimization configuration complete.
# Using threads = 8
# Mapper configuration complete.
# Initializing Index Factorization subspace.
#   Factorization options along problem dimension R = 1
#   Factorization options along problem dimension S = 1
#   Factorization options along problem dimension T = 1
#   Factorization options along problem dimension P = 1
#   Factorization options along problem dimension Q = 1
#   Factorization options along problem dimension F = 1
#   Factorization options along problem dimension C = 1
#   Factorization options along problem dimension M = 196
#   Factorization options along problem dimension N = 1
# Mapspace Dimension [IndexFactorization] Size: 196
# Mapspace Dimension [LoopPermutation] Size: 6292383221978976013516800000
# Mapspace Dimension [Spatial] Size: 10
# Mapspace Dimension [DatatypeBypass] Size: 64
# Mapspace split! Per-split Mapping Dimension [IndexFactorization] Size: 25 Residue: 4
# Mapspace construction complete.
# Search configuration complete.
# WARNING: no optimization metric(s) specified, using edp as default.
# WARNING: Interpreting 0 to mean full problem dimension instead of residue.
# WARNING: Interpreting 0 to mean full problem dimension instead of residue.
# WARNING: Interpreting 0 to mean full problem dimension instead of residue.
# WARNING: Interpreting 0 to mean full problem dimension instead of residue.
# WARNING: Interpreting 0 to mean full problem dimension instead of residue.
# WARNING: Interpreting 0 to mean full problem dimension instead of residue.
# WARNING: Interpreting 0 to mean full problem dimension instead of residue.
# [  0] Utilization = 1.00 | pJ/Compute =  281.245 | L5[WIO] F3 Q3 P218 - L4[] M2 T3 S3 R3 N16X - L3[] M10 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  0] Utilization = 1.00 | pJ/Compute =  270.760 | L5[WIO] F3 Q3 P218 - L4[I] M2 T3 S3 R3 N16X - L3[] M10 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  0] Utilization = 1.00 | pJ/Compute =   35.260 | L5[WIO] F3 Q3 P218 - L4[] M2 T3 S3 R3 N16X - L3[O] M10 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  0] Utilization = 1.00 | pJ/Compute =   24.774 | L5[WIO] F3 Q3 P218 - L4[I] M2 T3 S3 R3 N16X - L3[O] M10 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  3] Utilization = 1.00 | pJ/Compute =  149.866 | L5[WIO] F3 Q3 P218 - L4[] M20 T3 S3 R3 N16X - L3[] N1 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  3] Utilization = 1.00 | pJ/Compute =   25.390 | L5[WIO] F3 Q3 P218 - L4[I] M20 T3 S3 R3 N16X - L3[] N1 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  5] Utilization = 1.00 | pJ/Compute =  149.866 | L5[WIO] M2 F3 Q3 P218 - L4[] M10 T3 S3 R3 N16X - L3[] N1 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  5] Utilization = 1.00 | pJ/Compute =  141.954 | L5[WIO] M2 F3 Q3 P218 - L4[W] M10 T3 S3 R3 N16X - L3[] N1 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  5] Utilization = 1.00 | pJ/Compute =   27.570 | L5[WIO] M2 F3 Q3 P218 - L4[I] M10 T3 S3 R3 N16X - L3[] N1 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  4] STATEMENT: 1500 invalid mappings (1492 fanout, 8 capacity) found since the last valid mapping, terminating search.
# [  1] STATEMENT: 1500 invalid mappings (1493 fanout, 7 capacity) found since the last valid mapping, terminating search.
# [  6] Utilization = 1.00 | pJ/Compute =  332.835 | L5[WIO] M10 F3 Q3 P218 - L4[] T3 S3 R3 N16X - L3[] M2 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  6] Utilization = 1.00 | pJ/Compute =  324.924 | L5[WIO] M10 F3 Q3 P218 - L4[W] T3 S3 R3 N16X - L3[] M2 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  6] Utilization = 1.00 | pJ/Compute =  291.308 | L5[WIO] M10 F3 Q3 P218 - L4[I] T3 S3 R3 N16X - L3[] M2 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  6] Utilization = 1.00 | pJ/Compute =  283.396 | L5[WIO] M10 F3 Q3 P218 - L4[WI] T3 S3 R3 N16X - L3[] M2 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  2] STATEMENT: 1500 invalid mappings (1492 fanout, 8 capacity) found since the last valid mapping, terminating search.
# [  6] Utilization = 1.00 | pJ/Compute =   86.850 | L5[WIO] M10 F3 Q3 P218 - L4[] T3 S3 R3 N16X - L3[O] M2 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  6] Utilization = 1.00 | pJ/Compute =   78.938 | L5[WIO] M10 F3 Q3 P218 - L4[W] T3 S3 R3 N16X - L3[O] M2 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  6] Utilization = 1.00 | pJ/Compute =   45.322 | L5[WIO] M10 F3 Q3 P218 - L4[I] T3 S3 R3 N16X - L3[O] M2 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  6] Utilization = 1.00 | pJ/Compute =   37.410 | L5[WIO] M10 F3 Q3 P218 - L4[WI] T3 S3 R3 N16X - L3[O] M2 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  7] STATEMENT: 1500 invalid mappings (1472 fanout, 28 capacity) found since the last valid mapping, terminating search.
# [  6] Utilization = 1.00 | pJ/Compute =   30.002 | L5[WIO] F3 Q3 P218 M10 - L4[I] T3 S3 R3 N16X - L3[O] M2 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  6] Utilization = 1.00 | pJ/Compute =   29.690 | L5[WIO] F3 Q3 P218 M20 - L4[I] T3 S3 R3 N16X - L3[] N1 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  5] STATEMENT: 1500 invalid mappings (1482 fanout, 18 capacity) found since the last valid mapping, terminating search.
# [  0] STATEMENT: 800 suboptimal mappings found since the last upgrade, terminating search.
# [  3] STATEMENT: 800 suboptimal mappings found since the last upgrade, terminating search.
# [  6] STATEMENT: 800 suboptimal mappings found since the last upgrade, terminating search.
# Summary stats for best mapping found by mapper:
#   Utilization = 1.00 | pJ/Compute =   24.774
# 419.96 16951680 1059480
# HERE: designs/system_manual/arch/system_arch_1x16.yaml designs/system_manual/arch/components _layers/layer_shape_1.yaml _layers/map_1.yaml designs/system_auto/mapper/mapper.yaml
# input file: tmp.yaml
#   _______                __
#  /_  __(_)___ ___  ___  / /___  ____  ____
#   / / / / __ `__ \/ _ \/ / __ \/ __ \/ __ \
#  / / / / / / / / /  __/ / /_/ / /_/ / /_/ /
# /_/ /_/_/ /_/ /_/\___/_/\____/\____/ .___/
#                                   /_/
#
# Problem configuration complete.
# Warning: neither block size nor cluster size specified, set according to specified storage width: block size: 1  cluster-size: 1
# Warning: neither block size nor cluster size specified, set according to specified storage width: block size: 1  cluster-size: 1
# Warning: neither block size nor cluster size specified, set according to specified storage width: block size: 1  cluster-size: 1
# Warning: neither block size nor cluster size specified, set according to specified storage width: block size: 1  cluster-size: 1
# Warning: neither block size nor cluster size specified, set according to specified storage width: block size: 1  cluster-size: 1
# execute:/usr/local/bin/accelergy tmp.yaml --oprefix timeloop-mapper. -o ./ > timeloop-mapper.accelergy.log 2>&1
# Generate Accelergy ERT (energy reference table) to replace internal energy model.
# Generate Accelergy ART (area reference table) to replace internal area model.
# Architecture configuration complete.
# Sparse optimization configuration complete.
# Using threads = 8
# Mapper configuration complete.
# Initializing Index Factorization subspace.
#   Factorization options along problem dimension R = 1
#   Factorization options along problem dimension S = 1
#   Factorization options along problem dimension T = 1
#   Factorization options along problem dimension P = 1
#   Factorization options along problem dimension Q = 1
#   Factorization options along problem dimension F = 1
#   Factorization options along problem dimension C = 1
#   Factorization options along problem dimension M = 196
#   Factorization options along problem dimension N = 1
# Mapspace Dimension [IndexFactorization] Size: 196
# Mapspace Dimension [LoopPermutation] Size: 6292383221978976013516800000
# Mapspace Dimension [Spatial] Size: 10
# Mapspace Dimension [DatatypeBypass] Size: 64
# Mapspace split! Per-split Mapping Dimension [IndexFactorization] Size: 25 Residue: 4
# Mapspace construction complete.
# Search configuration complete.
# WARNING: no optimization metric(s) specified, using edp as default.
# WARNING: Interpreting 0 to mean full problem dimension instead of residue.
# WARNING: Interpreting 0 to mean full problem dimension instead of residue.
# WARNING: Interpreting 0 to mean full problem dimension instead of residue.
# WARNING: Interpreting 0 to mean full problem dimension instead of residue.
# WARNING: Interpreting 0 to mean full problem dimension instead of residue.
# WARNING: Interpreting 0 to mean full problem dimension instead of residue.
# WARNING: Interpreting 0 to mean full problem dimension instead of residue.
# [  0] Utilization = 1.00 | pJ/Compute =  283.873 | L5[WIO] C20 F3 Q3 P109 - L4[] M2 S3 N16X - L3[] M10 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  0] Utilization = 1.00 | pJ/Compute =  275.965 | L5[WIO] C20 F3 Q3 P109 - L4[W] M2 S3 N16X - L3[] M10 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  4] STATEMENT: 1500 invalid mappings (1492 fanout, 8 capacity) found since the last valid mapping, terminating search.
# [  2] STATEMENT: 1500 invalid mappings (1492 fanout, 8 capacity) found since the last valid mapping, terminating search.
# [  1] Utilization = 1.00 | pJ/Compute =  335.463 | L5[WIO] M2 C20 F3 Q3 P109 - L4[] M5 S3 N16X - L3[] M2 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  0] Utilization = 1.00 | pJ/Compute =  269.780 | L5[WIO] C20 F3 Q3 P109 - L4[WI] M2 S3 N16X - L3[] M10 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  1] Utilization = 1.00 | pJ/Compute =  327.555 | L5[WIO] M2 C20 F3 Q3 P109 - L4[W] M5 S3 N16X - L3[] M2 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  0] Utilization = 1.00 | pJ/Compute =  113.823 | L5[WIO] C20 F3 Q3 P109 - L4[] M2 S3 N16X - L3[O] M10 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  0] Utilization = 1.00 | pJ/Compute =  105.916 | L5[WIO] C20 F3 Q3 P109 - L4[W] M2 S3 N16X - L3[O] M10 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  1] Utilization = 1.00 | pJ/Compute =  285.096 | L5[WIO] M2 C20 F3 Q3 P109 - L4[I] M5 S3 N16X - L3[] M2 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  1] Utilization = 1.00 | pJ/Compute =  277.188 | L5[WIO] M2 C20 F3 Q3 P109 - L4[WI] M5 S3 N16X - L3[] M2 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  0] Utilization = 1.00 | pJ/Compute =   99.731 | L5[WIO] C20 F3 Q3 P109 - L4[WI] M2 S3 N16X - L3[O] M10 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  1] Utilization = 1.00 | pJ/Compute =  165.413 | L5[WIO] M2 C20 F3 Q3 P109 - L4[] M5 S3 N16X - L3[O] M2 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  1] Utilization = 1.00 | pJ/Compute =  157.506 | L5[WIO] M2 C20 F3 Q3 P109 - L4[W] M5 S3 N16X - L3[O] M2 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  1] Utilization = 1.00 | pJ/Compute =  115.046 | L5[WIO] M2 C20 F3 Q3 P109 - L4[I] M5 S3 N16X - L3[O] M2 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  1] Utilization = 1.00 | pJ/Compute =  107.139 | L5[WIO] M2 C20 F3 Q3 P109 - L4[WI] M5 S3 N16X - L3[O] M2 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  3] Utilization = 1.00 | pJ/Compute =  228.634 | L5[WIO] C20 F3 Q3 P109 - L4[] M20 S3 N16X - L3[] N1 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  3] Utilization = 1.00 | pJ/Compute =  220.726 | L5[WIO] C20 F3 Q3 P109 - L4[W] M20 S3 N16X - L3[] N1 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  5] Utilization = 1.00 | pJ/Compute =  228.634 | L5[WIO] M2 C20 F3 Q3 P109 - L4[] M10 S3 N16X - L3[] N1 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  5] Utilization = 1.00 | pJ/Compute =  220.726 | L5[WIO] M2 C20 F3 Q3 P109 - L4[W] M10 S3 N16X - L3[] N1 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  3] Utilization = 1.00 | pJ/Compute =  108.458 | L5[WIO] C20 F3 Q3 P109 - L4[I] M20 S3 N16X - L3[] N1 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  3] Utilization = 1.00 | pJ/Compute =  100.550 | L5[WIO] C20 F3 Q3 P109 - L4[WI] M20 S3 N16X - L3[] N1 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  5] Utilization = 1.00 | pJ/Compute =  114.939 | L5[WIO] M2 C20 F3 Q3 P109 - L4[I] M10 S3 N16X - L3[] N1 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  5] Utilization = 1.00 | pJ/Compute =  107.031 | L5[WIO] M2 C20 F3 Q3 P109 - L4[WI] M10 S3 N16X - L3[] N1 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  7] STATEMENT: 1500 invalid mappings (1471 fanout, 29 capacity) found since the last valid mapping, terminating search.
# [  6] Utilization = 1.00 | pJ/Compute =  335.463 | L5[WIO] M10 C20 F3 Q3 P109 - L4[] S3 N16X - L3[] M2 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  6] Utilization = 1.00 | pJ/Compute =  327.555 | L5[WIO] M10 C20 F3 Q3 P109 - L4[W] S3 N16X - L3[] M2 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  6] Utilization = 1.00 | pJ/Compute =  165.413 | L5[WIO] M10 C20 F3 Q3 P109 - L4[] S3 N16X - L3[O] M2 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  6] Utilization = 1.00 | pJ/Compute =  157.506 | L5[WIO] M10 C20 F3 Q3 P109 - L4[W] S3 N16X - L3[O] M2 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  0] Utilization = 1.00 | pJ/Compute =   96.824 | L5[WIO] C20 F3 P109 Q3 - L4[WI] M2 S3 N16X - L3[O] M10 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  3] Utilization = 1.00 | pJ/Compute =   97.670 | L5[WIO] C20 F3 P109 Q3 - L4[WI] M20 S3 N16X - L3[] N1 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  6] Utilization = 1.00 | pJ/Compute =  151.083 | L5[WIO] M10 C20 F3 P109 Q3 - L4[] S3 N16X - L3[O] M2 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  6] Utilization = 1.00 | pJ/Compute =  143.175 | L5[WIO] M10 C20 F3 P109 Q3 - L4[W] S3 N16X - L3[O] M2 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  6] Utilization = 1.00 | pJ/Compute =  137.831 | L5[WIO] M10 C20 F3 P109 Q3 - L4[I] S3 N16X - L3[O] M2 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  6] Utilization = 1.00 | pJ/Compute =  129.923 | L5[WIO] M10 C20 F3 P109 Q3 - L4[WI] S3 N16X - L3[O] M2 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  0] Utilization = 1.00 | pJ/Compute =   35.099 | L5[WIO] F3 Q3 P109 C20 - L4[O] M2 S3 N16X - L3[] M10 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  0] Utilization = 1.00 | pJ/Compute =   28.914 | L5[WIO] F3 Q3 P109 C20 - L4[IO] M2 S3 N16X - L3[] M10 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  3] Utilization = 1.00 | pJ/Compute =   28.381 | L5[WIO] F3 Q3 P109 C20 - L4[IO] M20 S3 N16X - L3[] N1 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  0] Utilization = 1.00 | pJ/Compute =   27.561 | L5[WIO] F3 Q3 P109 C20 - L4[IO] M2 S3 N16X - L3[O] M10 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  5] Utilization = 1.00 | pJ/Compute =  101.270 | L5[WIO] M2 C20 F3 P109 Q3 - L4[WI] M10 S3 N16X - L3[] N1 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  1] Utilization = 1.00 | pJ/Compute =  101.327 | L5[WIO] M2 C20 F3 P109 Q3 - L4[WI] M5 S3 N16X - L3[O] M2 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  6] Utilization = 1.00 | pJ/Compute =   84.262 | L5[WIO] M10 F3 Q3 P109 C20 - L4[] S3 N16X - L3[O] M2 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  5] Utilization = 1.00 | pJ/Compute =   34.862 | L5[WIO] M2 F3 Q3 P109 C20 - L4[IO] M10 S3 N16X - L3[] N1 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  1] Utilization = 1.00 | pJ/Compute =   86.689 | L5[WIO] M2 F3 Q3 P109 C20 - L4[O] M5 S3 N16X - L3[] M2 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  1] Utilization = 1.00 | pJ/Compute =   36.323 | L5[WIO] M2 F3 Q3 P109 C20 - L4[IO] M5 S3 N16X - L3[] M2 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  1] Utilization = 1.00 | pJ/Compute =   34.969 | L5[WIO] M2 F3 Q3 P109 C20 - L4[IO] M5 S3 N16X - L3[O] M2 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  5] STATEMENT: 1500 invalid mappings (1482 fanout, 18 capacity) found since the last valid mapping, terminating search.
# [  1] STATEMENT: 1500 invalid mappings (1484 fanout, 16 capacity) found since the last valid mapping, terminating search.
# [  6] Utilization = 1.00 | pJ/Compute =   47.823 | L5[WIO] M4 F3 Q3 P109 C20 - L4[IO] M5 S3 N16X - L3[] N1 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  0] STATEMENT: 800 suboptimal mappings found since the last upgrade, terminating search.
# [  3] STATEMENT: 800 suboptimal mappings found since the last upgrade, terminating search.
# [  6] STATEMENT: 800 suboptimal mappings found since the last upgrade, terminating search.
# Summary stats for best mapping found by mapper:
#   Utilization = 1.00 | pJ/Compute =   27.561
# 519.12 18835200 1177200
# HERE: designs/system_manual/arch/system_arch_1x16.yaml designs/system_manual/arch/components _layers/layer_shape_2.yaml _layers/map_2.yaml designs/system_auto/mapper/mapper.yaml
# input file: tmp.yaml
#   _______                __
#  /_  __(_)___ ___  ___  / /___  ____  ____
#   / / / / __ `__ \/ _ \/ / __ \/ __ \/ __ \
#  / / / / / / / / /  __/ / /_/ / /_/ / /_/ /
# /_/ /_/_/ /_/ /_/\___/_/\____/\____/ .___/
#                                   /_/
#
# Problem configuration complete.
# Warning: neither block size nor cluster size specified, set according to specified storage width: block size: 1  cluster-size: 1
# Warning: neither block size nor cluster size specified, set according to specified storage width: block size: 1  cluster-size: 1
# Warning: neither block size nor cluster size specified, set according to specified storage width: block size: 1  cluster-size: 1
# Warning: neither block size nor cluster size specified, set according to specified storage width: block size: 1  cluster-size: 1
# Warning: neither block size nor cluster size specified, set according to specified storage width: block size: 1  cluster-size: 1
# execute:/usr/local/bin/accelergy tmp.yaml --oprefix timeloop-mapper. -o ./ > timeloop-mapper.accelergy.log 2>&1
# Generate Accelergy ERT (energy reference table) to replace internal energy model.
# Generate Accelergy ART (area reference table) to replace internal area model.
# Architecture configuration complete.
# Sparse optimization configuration complete.
# Using threads = 8
# Mapper configuration complete.
# Initializing Index Factorization subspace.
#   Factorization options along problem dimension R = 1
#   Factorization options along problem dimension S = 1
#   Factorization options along problem dimension T = 1
#   Factorization options along problem dimension P = 1
#   Factorization options along problem dimension Q = 1
#   Factorization options along problem dimension F = 1
#   Factorization options along problem dimension C = 1
#   Factorization options along problem dimension M = 196
#   Factorization options along problem dimension N = 1
# Mapspace Dimension [IndexFactorization] Size: 196
# Mapspace Dimension [LoopPermutation] Size: 6292383221978976013516800000
# Mapspace Dimension [Spatial] Size: 10
# Mapspace Dimension [DatatypeBypass] Size: 64
# Mapspace split! Per-split Mapping Dimension [IndexFactorization] Size: 25 Residue: 4
# Mapspace construction complete.
# Search configuration complete.
# WARNING: no optimization metric(s) specified, using edp as default.
# WARNING: Interpreting 0 to mean full problem dimension instead of residue.
# WARNING: Interpreting 0 to mean full problem dimension instead of residue.
# WARNING: Interpreting 0 to mean full problem dimension instead of residue.
# WARNING: Interpreting 0 to mean full problem dimension instead of residue.
# WARNING: Interpreting 0 to mean full problem dimension instead of residue.
# WARNING: Interpreting 0 to mean full problem dimension instead of residue.
# WARNING: Interpreting 0 to mean full problem dimension instead of residue.
# [  2] Utilization = 1.00 | pJ/Compute =  298.681 | L5[WIO] M3 C20 P109 - L4[] M5 T3 S3 R3 N16X - L3[] M5 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  2] Utilization = 1.00 | pJ/Compute =  275.110 | L5[WIO] M3 C20 P109 - L4[I] M5 T3 S3 R3 N16X - L3[] M5 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  2] Utilization = 1.00 | pJ/Compute =   52.705 | L5[WIO] M3 C20 P109 - L4[] M5 T3 S3 R3 N16X - L3[O] M5 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  2] Utilization = 1.00 | pJ/Compute =   29.133 | L5[WIO] M3 C20 P109 - L4[I] M5 T3 S3 R3 N16X - L3[O] M5 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  3] Utilization = 1.00 | pJ/Compute =  315.878 | L5[WIO] M5 C20 P109 - L4[] M5 T3 S3 R3 N16X - L3[] M3 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  3] Utilization = 1.00 | pJ/Compute =  308.036 | L5[WIO] M5 C20 P109 - L4[W] M5 T3 S3 R3 N16X - L3[] M3 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  3] Utilization = 1.00 | pJ/Compute =  276.592 | L5[WIO] M5 C20 P109 - L4[I] M5 T3 S3 R3 N16X - L3[] M3 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  3] Utilization = 1.00 | pJ/Compute =   69.901 | L5[WIO] M5 C20 P109 - L4[] M5 T3 S3 R3 N16X - L3[O] M3 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  3] Utilization = 1.00 | pJ/Compute =   62.060 | L5[WIO] M5 C20 P109 - L4[W] M5 T3 S3 R3 N16X - L3[O] M3 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  7] Utilization = 1.00 | pJ/Compute =  315.878 | L5[WIO] M25 C20 P109 - L4[] T3 S3 R3 N16X - L3[] M3 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  3] Utilization = 1.00 | pJ/Compute =   30.616 | L5[WIO] M5 C20 P109 - L4[I] M5 T3 S3 R3 N16X - L3[O] M3 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  7] Utilization = 1.00 | pJ/Compute =  308.036 | L5[WIO] M25 C20 P109 - L4[W] T3 S3 R3 N16X - L3[] M3 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  1] Utilization = 1.00 | pJ/Compute =  281.484 | L5[WIO] M5 C20 P109 - L4[] T3 S3 R3 N16X - L3[] M15 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  6] Utilization = 1.00 | pJ/Compute =  315.878 | L5[WIO] C20 P109 - L4[] M25 T3 S3 R3 N16X - L3[] M3 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  1] Utilization = 1.00 | pJ/Compute =  273.643 | L5[WIO] M5 C20 P109 - L4[W] T3 S3 R3 N16X - L3[] M15 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  7] Utilization = 1.00 | pJ/Compute =  288.325 | L5[WIO] M25 C20 P109 - L4[I] T3 S3 R3 N16X - L3[] M3 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  6] Utilization = 1.00 | pJ/Compute =  274.246 | L5[WIO] C20 P109 - L4[I] M25 T3 S3 R3 N16X - L3[] M3 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  1] Utilization = 1.00 | pJ/Compute =   35.508 | L5[WIO] M5 C20 P109 - L4[] T3 S3 R3 N16X - L3[O] M15 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  1] Utilization = 1.00 | pJ/Compute =   27.666 | L5[WIO] M5 C20 P109 - L4[W] T3 S3 R3 N16X - L3[O] M15 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  7] Utilization = 1.00 | pJ/Compute =   69.901 | L5[WIO] M25 C20 P109 - L4[] T3 S3 R3 N16X - L3[O] M3 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  4] Utilization = 1.00 | pJ/Compute =  298.681 | L5[WIO] C20 P109 - L4[] M15 T3 S3 R3 N16X - L3[] M5 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  5] Utilization = 1.00 | pJ/Compute =  278.045 | L5[WIO] M3 C20 P109 - L4[] T3 S3 R3 N16X - L3[] M25 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  4] Utilization = 1.00 | pJ/Compute =  273.936 | L5[WIO] C20 P109 - L4[I] M15 T3 S3 R3 N16X - L3[] M5 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  6] Utilization = 1.00 | pJ/Compute =   69.901 | L5[WIO] C20 P109 - L4[] M25 T3 S3 R3 N16X - L3[O] M3 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  4] Utilization = 1.00 | pJ/Compute =   52.705 | L5[WIO] C20 P109 - L4[] M15 T3 S3 R3 N16X - L3[O] M5 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  7] Utilization = 1.00 | pJ/Compute =   62.060 | L5[WIO] M25 C20 P109 - L4[W] T3 S3 R3 N16X - L3[O] M3 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  4] Utilization = 1.00 | pJ/Compute =   27.960 | L5[WIO] C20 P109 - L4[I] M15 T3 S3 R3 N16X - L3[O] M5 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  7] Utilization = 1.00 | pJ/Compute =   42.348 | L5[WIO] M25 C20 P109 - L4[I] T3 S3 R3 N16X - L3[O] M3 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  6] Utilization = 1.00 | pJ/Compute =   28.269 | L5[WIO] C20 P109 - L4[I] M25 T3 S3 R3 N16X - L3[O] M3 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  5] Utilization = 1.00 | pJ/Compute =  274.739 | L5[WIO] M3 C20 P109 - L4[I] T3 S3 R3 N16X - L3[] M25 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  5] Utilization = 1.00 | pJ/Compute =   32.069 | L5[WIO] M3 C20 P109 - L4[] T3 S3 R3 N16X - L3[O] M25 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  0] STATEMENT: 1500 invalid mappings (1464 fanout, 36 capacity) found since the last valid mapping, terminating search.
# [  5] Utilization = 1.00 | pJ/Compute =   28.762 | L5[WIO] M3 C20 P109 - L4[I] T3 S3 R3 N16X - L3[O] M25 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  1] Utilization = 1.00 | pJ/Compute =   26.491 | L5[WIO] M5 P109 C20 - L4[] T3 S3 R3 N16X - L3[O] M15 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  5] Utilization = 1.00 | pJ/Compute =   23.052 | L5[WIO] M3 P109 C20 - L4[] T3 S3 R3 N16X - L3[O] M25 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  7] Utilization = 1.00 | pJ/Compute =   29.411 | L5[WIO] C20 P109 M25 - L4[I] T3 S3 R3 N16X - L3[O] M3 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  2] Utilization = 1.00 | pJ/Compute =   25.475 | L5[WIO] M3 P109 C20 - L4[O] T3 S3 R3 M5 N16X - L3[] M5 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  3] Utilization = 1.00 | pJ/Compute =   28.915 | L5[WIO] M5 P109 C20 - L4[O] T3 S3 R3 M5 N16X - L3[] M3 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  4] STATEMENT: 1500 invalid mappings (1482 fanout, 18 capacity) found since the last valid mapping, terminating search.
# [  3] Utilization = 1.00 | pJ/Compute =   28.334 | L5[WIO] C20 P109 - L4[I] M75 T3 S3 R3 N16X - L3[] N1 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  7] STATEMENT: 1500 invalid mappings (1491 fanout, 9 capacity) found since the last valid mapping, terminating search.
# [  6] Utilization = 1.00 | pJ/Compute =   25.475 | L5[WIO] M3 P109 C20 - L4[O] T3 S3 R3 M25 N16X - L3[] N1 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  2] STATEMENT: 800 suboptimal mappings found since the last upgrade, terminating search.
# [  5] STATEMENT: 800 suboptimal mappings found since the last upgrade, terminating search.
# [  1] STATEMENT: 800 suboptimal mappings found since the last upgrade, terminating search.
# [  3] STATEMENT: 800 suboptimal mappings found since the last upgrade, terminating search.
# [  6] STATEMENT: 800 suboptimal mappings found since the last upgrade, terminating search.
# Summary stats for best mapping found by mapper:
#   Utilization = 1.00 | pJ/Compute =   23.052
# 1628.2 70632000 4414500
# HERE: designs/system_manual/arch/system_arch_1x16.yaml designs/system_manual/arch/components _layers/layer_shape_3.yaml _layers/map_3.yaml designs/system_auto/mapper/mapper.yaml
# input file: tmp.yaml
#   _______                __
#  /_  __(_)___ ___  ___  / /___  ____  ____
#   / / / / __ `__ \/ _ \/ / __ \/ __ \/ __ \
#  / / / / / / / / /  __/ / /_/ / /_/ / /_/ /
# /_/ /_/_/ /_/ /_/\___/_/\____/\____/ .___/
#                                   /_/
#
# Problem configuration complete.
# Warning: neither block size nor cluster size specified, set according to specified storage width: block size: 1  cluster-size: 1
# Warning: neither block size nor cluster size specified, set according to specified storage width: block size: 1  cluster-size: 1
# Warning: neither block size nor cluster size specified, set according to specified storage width: block size: 1  cluster-size: 1
# Warning: neither block size nor cluster size specified, set according to specified storage width: block size: 1  cluster-size: 1
# Warning: neither block size nor cluster size specified, set according to specified storage width: block size: 1  cluster-size: 1
# execute:/usr/local/bin/accelergy tmp.yaml --oprefix timeloop-mapper. -o ./ > timeloop-mapper.accelergy.log 2>&1
# Generate Accelergy ERT (energy reference table) to replace internal energy model.
# Generate Accelergy ART (area reference table) to replace internal area model.
# Architecture configuration complete.
# Sparse optimization configuration complete.
# Using threads = 8
# Mapper configuration complete.
# Initializing Index Factorization subspace.
#   Factorization options along problem dimension R = 1
#   Factorization options along problem dimension S = 1
#   Factorization options along problem dimension T = 1
#   Factorization options along problem dimension P = 1
#   Factorization options along problem dimension Q = 1
#   Factorization options along problem dimension F = 1
#   Factorization options along problem dimension C = 1
#   Factorization options along problem dimension M = 196
#   Factorization options along problem dimension N = 1
# Mapspace Dimension [IndexFactorization] Size: 196
# Mapspace Dimension [LoopPermutation] Size: 6292383221978976013516800000
# Mapspace Dimension [Spatial] Size: 10
# Mapspace Dimension [DatatypeBypass] Size: 64
# Mapspace split! Per-split Mapping Dimension [IndexFactorization] Size: 25 Residue: 4
# Mapspace construction complete.
# Search configuration complete.
# WARNING: no optimization metric(s) specified, using edp as default.
# WARNING: Interpreting 0 to mean full problem dimension instead of residue.
# WARNING: Interpreting 0 to mean full problem dimension instead of residue.
# WARNING: Interpreting 0 to mean full problem dimension instead of residue.
# WARNING: Interpreting 0 to mean full problem dimension instead of residue.
# WARNING: Interpreting 0 to mean full problem dimension instead of residue.
# WARNING: Interpreting 0 to mean full problem dimension instead of residue.
# WARNING: Interpreting 0 to mean full problem dimension instead of residue.
# [  2] Utilization = 1.00 | pJ/Compute =  298.347 | L5[WIO] M3 C75 P55 - L4[] M5 S3 N16X - L3[] M5 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  2] Utilization = 1.00 | pJ/Compute =  290.578 | L5[WIO] M3 C75 P55 - L4[W] M5 S3 N16X - L3[] M5 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  2] Utilization = 1.00 | pJ/Compute =  278.200 | L5[WIO] M3 C75 P55 - L4[I] M5 S3 N16X - L3[] M5 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  2] Utilization = 1.00 | pJ/Compute =  270.431 | L5[WIO] M3 C75 P55 - L4[WI] M5 S3 N16X - L3[] M5 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  2] Utilization = 1.00 | pJ/Compute =  128.300 | L5[WIO] M3 C75 P55 - L4[] M5 S3 N16X - L3[O] M5 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  2] Utilization = 1.00 | pJ/Compute =  120.532 | L5[WIO] M3 C75 P55 - L4[W] M5 S3 N16X - L3[O] M5 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  7] Utilization = 1.00 | pJ/Compute =  315.543 | L5[WIO] M25 C75 P55 - L4[] S3 N16X - L3[] M3 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  7] Utilization = 1.00 | pJ/Compute =  307.775 | L5[WIO] M25 C75 P55 - L4[W] S3 N16X - L3[] M3 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  2] Utilization = 1.00 | pJ/Compute =  108.154 | L5[WIO] M3 C75 P55 - L4[I] M5 S3 N16X - L3[O] M5 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  2] Utilization = 1.00 | pJ/Compute =  100.385 | L5[WIO] M3 C75 P55 - L4[WI] M5 S3 N16X - L3[O] M5 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  7] Utilization = 1.00 | pJ/Compute =  145.497 | L5[WIO] M25 C75 P55 - L4[] S3 N16X - L3[O] M3 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  5] Utilization = 1.00 | pJ/Compute =  277.711 | L5[WIO] M3 C75 P55 - L4[] S3 N16X - L3[] M25 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  5] Utilization = 1.00 | pJ/Compute =  269.942 | L5[WIO] M3 C75 P55 - L4[W] S3 N16X - L3[] M25 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  7] Utilization = 1.00 | pJ/Compute =  137.728 | L5[WIO] M25 C75 P55 - L4[W] S3 N16X - L3[O] M3 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  6] Utilization = 1.00 | pJ/Compute =  315.543 | L5[WIO] C75 P55 - L4[] M25 S3 N16X - L3[] M3 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  6] Utilization = 1.00 | pJ/Compute =  307.775 | L5[WIO] C75 P55 - L4[W] M25 S3 N16X - L3[] M3 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  6] Utilization = 1.00 | pJ/Compute =  275.053 | L5[WIO] C75 P55 - L4[I] M25 S3 N16X - L3[] M3 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  6] Utilization = 1.00 | pJ/Compute =  267.284 | L5[WIO] C75 P55 - L4[WI] M25 S3 N16X - L3[] M3 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  3] Utilization = 1.00 | pJ/Compute =  315.543 | L5[WIO] M5 C75 P55 - L4[] M5 S3 N16X - L3[] M3 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  3] Utilization = 1.00 | pJ/Compute =  307.775 | L5[WIO] M5 C75 P55 - L4[W] M5 S3 N16X - L3[] M3 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  6] Utilization = 1.00 | pJ/Compute =  145.497 | L5[WIO] C75 P55 - L4[] M25 S3 N16X - L3[O] M3 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  6] Utilization = 1.00 | pJ/Compute =  137.728 | L5[WIO] C75 P55 - L4[W] M25 S3 N16X - L3[O] M3 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  3] Utilization = 1.00 | pJ/Compute =  281.965 | L5[WIO] M5 C75 P55 - L4[I] M5 S3 N16X - L3[] M3 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  3] Utilization = 1.00 | pJ/Compute =  274.197 | L5[WIO] M5 C75 P55 - L4[WI] M5 S3 N16X - L3[] M3 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  6] Utilization = 1.00 | pJ/Compute =  105.007 | L5[WIO] C75 P55 - L4[I] M25 S3 N16X - L3[O] M3 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  6] Utilization = 1.00 | pJ/Compute =   97.238 | L5[WIO] C75 P55 - L4[WI] M25 S3 N16X - L3[O] M3 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  3] Utilization = 1.00 | pJ/Compute =  145.497 | L5[WIO] M5 C75 P55 - L4[] M5 S3 N16X - L3[O] M3 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  3] Utilization = 1.00 | pJ/Compute =  137.728 | L5[WIO] M5 C75 P55 - L4[W] M5 S3 N16X - L3[O] M3 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  1] Utilization = 1.00 | pJ/Compute =  281.150 | L5[WIO] M5 C75 P55 - L4[] S3 N16X - L3[] M15 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  1] Utilization = 1.00 | pJ/Compute =  273.381 | L5[WIO] M5 C75 P55 - L4[W] S3 N16X - L3[] M15 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  5] Utilization = 1.00 | pJ/Compute =  107.664 | L5[WIO] M3 C75 P55 - L4[] S3 N16X - L3[O] M25 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  5] Utilization = 1.00 | pJ/Compute =   99.896 | L5[WIO] M3 C75 P55 - L4[W] S3 N16X - L3[O] M25 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  1] Utilization = 1.00 | pJ/Compute =  111.104 | L5[WIO] M5 C75 P55 - L4[] S3 N16X - L3[O] M15 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  1] Utilization = 1.00 | pJ/Compute =  103.335 | L5[WIO] M5 C75 P55 - L4[W] S3 N16X - L3[O] M15 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  3] Utilization = 1.00 | pJ/Compute =  111.919 | L5[WIO] M5 C75 P55 - L4[I] M5 S3 N16X - L3[O] M3 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  3] Utilization = 1.00 | pJ/Compute =  104.150 | L5[WIO] M5 C75 P55 - L4[WI] M5 S3 N16X - L3[O] M3 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  4] Utilization = 1.00 | pJ/Compute =  298.347 | L5[WIO] C75 P55 - L4[] M15 S3 N16X - L3[] M5 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  4] Utilization = 1.00 | pJ/Compute =  290.578 | L5[WIO] C75 P55 - L4[W] M15 S3 N16X - L3[] M5 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  4] Utilization = 1.00 | pJ/Compute =  274.744 | L5[WIO] C75 P55 - L4[I] M15 S3 N16X - L3[] M5 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  4] Utilization = 1.00 | pJ/Compute =  266.975 | L5[WIO] C75 P55 - L4[WI] M15 S3 N16X - L3[] M5 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  4] Utilization = 1.00 | pJ/Compute =  128.300 | L5[WIO] C75 P55 - L4[] M15 S3 N16X - L3[O] M5 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  4] Utilization = 1.00 | pJ/Compute =  120.532 | L5[WIO] C75 P55 - L4[W] M15 S3 N16X - L3[O] M5 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  4] Utilization = 1.00 | pJ/Compute =  104.697 | L5[WIO] C75 P55 - L4[I] M15 S3 N16X - L3[O] M5 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  4] Utilization = 1.00 | pJ/Compute =   96.929 | L5[WIO] C75 P55 - L4[WI] M15 S3 N16X - L3[O] M5 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  7] Utilization = 1.00 | pJ/Compute =   61.214 | L5[WIO] M25 P55 C75 - L4[] S3 N16X - L3[O] M3 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  5] Utilization = 1.00 | pJ/Compute =   23.381 | L5[WIO] M3 P55 C75 - L4[] S3 N16X - L3[O] M25 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  2] Utilization = 1.00 | pJ/Compute =   46.441 | L5[WIO] M3 P55 C75 - L4[O] M5 S3 N16X - L3[] M5 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  2] Utilization = 1.00 | pJ/Compute =   26.294 | L5[WIO] M3 P55 C75 - L4[IO] M5 S3 N16X - L3[] M5 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  2] Utilization = 1.00 | pJ/Compute =   24.945 | L5[WIO] M3 P55 C75 - L4[IO] M5 S3 N16X - L3[O] M5 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  1] Utilization = 1.00 | pJ/Compute =   26.821 | L5[WIO] M5 P55 C75 - L4[] S3 N16X - L3[O] M15 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  0] STATEMENT: 1500 invalid mappings (1323 fanout, 177 capacity) found since the last valid mapping, terminating search.
# [  3] Utilization = 1.00 | pJ/Compute =   63.638 | L5[WIO] M5 P55 C75 - L4[O] M5 S3 N16X - L3[] M3 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  3] Utilization = 1.00 | pJ/Compute =   30.060 | L5[WIO] M5 P55 C75 - L4[IO] M5 S3 N16X - L3[] M3 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  3] Utilization = 1.00 | pJ/Compute =   28.710 | L5[WIO] M5 P55 C75 - L4[IO] M5 S3 N16X - L3[O] M3 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  6] Utilization = 1.00 | pJ/Compute =   46.441 | L5[WIO] M5 P55 C75 - L4[O] M3 S3 N16X - L3[] M5 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  6] Utilization = 1.00 | pJ/Compute =   29.751 | L5[WIO] M5 P55 C75 - L4[IO] M3 S3 N16X - L3[] M5 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  6] Utilization = 1.00 | pJ/Compute =   28.401 | L5[WIO] M5 P55 C75 - L4[IO] M3 S3 N16X - L3[O] M5 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  6] Utilization = 1.00 | pJ/Compute =   25.529 | L5[WIO] M3 P55 C75 - L4[IO] M25 S3 N16X - L3[] N1 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  2] STATEMENT: 800 suboptimal mappings found since the last upgrade, terminating search.
# [  4] STATEMENT: 800 suboptimal mappings found since the last upgrade, terminating search.
# [  7] STATEMENT: 800 suboptimal mappings found since the last upgrade, terminating search.
# [  5] STATEMENT: 800 suboptimal mappings found since the last upgrade, terminating search.
# [  6] STATEMENT: 800 suboptimal mappings found since the last upgrade, terminating search.
# [  3] STATEMENT: 800 suboptimal mappings found since the last upgrade, terminating search.
# [  1] STATEMENT: 800 suboptimal mappings found since the last upgrade, terminating search.
# Summary stats for best mapping found by mapper:
#   Utilization = 1.00 | pJ/Compute =   23.381
# 347.21 14850000 928125
# HERE: designs/system_manual/arch/system_arch_1x16.yaml designs/system_manual/arch/components _layers/layer_shape_4.yaml _layers/map_4.yaml designs/system_auto/mapper/mapper.yaml
# input file: tmp.yaml
#   _______                __
#  /_  __(_)___ ___  ___  / /___  ____  ____
#   / / / / __ `__ \/ _ \/ / __ \/ __ \/ __ \
#  / / / / / / / / /  __/ / /_/ / /_/ / /_/ /
# /_/ /_/_/ /_/ /_/\___/_/\____/\____/ .___/
#                                   /_/
#
# Problem configuration complete.
# Warning: neither block size nor cluster size specified, set according to specified storage width: block size: 1  cluster-size: 1
# Warning: neither block size nor cluster size specified, set according to specified storage width: block size: 1  cluster-size: 1
# Warning: neither block size nor cluster size specified, set according to specified storage width: block size: 1  cluster-size: 1
# Warning: neither block size nor cluster size specified, set according to specified storage width: block size: 1  cluster-size: 1
# Warning: neither block size nor cluster size specified, set according to specified storage width: block size: 1  cluster-size: 1
# execute:/usr/local/bin/accelergy tmp.yaml --oprefix timeloop-mapper. -o ./ > timeloop-mapper.accelergy.log 2>&1
# Generate Accelergy ERT (energy reference table) to replace internal energy model.
# Generate Accelergy ART (area reference table) to replace internal area model.
# Architecture configuration complete.
# Sparse optimization configuration complete.
# Using threads = 8
# Mapper configuration complete.
# Initializing Index Factorization subspace.
#   Factorization options along problem dimension R = 1
#   Factorization options along problem dimension S = 1
#   Factorization options along problem dimension T = 1
#   Factorization options along problem dimension P = 1
#   Factorization options along problem dimension Q = 1
#   Factorization options along problem dimension F = 1
#   Factorization options along problem dimension C = 1
#   Factorization options along problem dimension M = 196
#   Factorization options along problem dimension N = 1
# Mapspace Dimension [IndexFactorization] Size: 196
# Mapspace Dimension [LoopPermutation] Size: 6292383221978976013516800000
# Mapspace Dimension [Spatial] Size: 10
# Mapspace Dimension [DatatypeBypass] Size: 64
# Mapspace split! Per-split Mapping Dimension [IndexFactorization] Size: 25 Residue: 4
# Mapspace construction complete.
# Search configuration complete.
# WARNING: no optimization metric(s) specified, using edp as default.
# WARNING: Interpreting 0 to mean full problem dimension instead of residue.
# WARNING: Interpreting 0 to mean full problem dimension instead of residue.
# WARNING: Interpreting 0 to mean full problem dimension instead of residue.
# WARNING: Interpreting 0 to mean full problem dimension instead of residue.
# WARNING: Interpreting 0 to mean full problem dimension instead of residue.
# WARNING: Interpreting 0 to mean full problem dimension instead of residue.
# WARNING: Interpreting 0 to mean full problem dimension instead of residue.
# [  2] Utilization = 1.00 | pJ/Compute =  298.347 | L5[WIO] M3 C75 P55 - L4[] M5 S3 N16X - L3[] M5 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  2] Utilization = 1.00 | pJ/Compute =  290.578 | L5[WIO] M3 C75 P55 - L4[W] M5 S3 N16X - L3[] M5 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  2] Utilization = 1.00 | pJ/Compute =  278.200 | L5[WIO] M3 C75 P55 - L4[I] M5 S3 N16X - L3[] M5 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  2] Utilization = 1.00 | pJ/Compute =  270.431 | L5[WIO] M3 C75 P55 - L4[WI] M5 S3 N16X - L3[] M5 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  5] Utilization = 1.00 | pJ/Compute =  277.711 | L5[WIO] M3 C75 P55 - L4[] S3 N16X - L3[] M25 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  5] Utilization = 1.00 | pJ/Compute =  269.942 | L5[WIO] M3 C75 P55 - L4[W] S3 N16X - L3[] M25 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  2] Utilization = 1.00 | pJ/Compute =  128.300 | L5[WIO] M3 C75 P55 - L4[] M5 S3 N16X - L3[O] M5 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  2] Utilization = 1.00 | pJ/Compute =  120.532 | L5[WIO] M3 C75 P55 - L4[W] M5 S3 N16X - L3[O] M5 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  3] Utilization = 1.00 | pJ/Compute =  315.543 | L5[WIO] M5 C75 P55 - L4[] M5 S3 N16X - L3[] M3 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  6] Utilization = 1.00 | pJ/Compute =  315.543 | L5[WIO] C75 P55 - L4[] M25 S3 N16X - L3[] M3 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  3] Utilization = 1.00 | pJ/Compute =  307.775 | L5[WIO] M5 C75 P55 - L4[W] M5 S3 N16X - L3[] M3 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  2] Utilization = 1.00 | pJ/Compute =  108.154 | L5[WIO] M3 C75 P55 - L4[I] M5 S3 N16X - L3[O] M5 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  6] Utilization = 1.00 | pJ/Compute =  307.775 | L5[WIO] C75 P55 - L4[W] M25 S3 N16X - L3[] M3 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  2] Utilization = 1.00 | pJ/Compute =  100.385 | L5[WIO] M3 C75 P55 - L4[WI] M5 S3 N16X - L3[O] M5 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  3] Utilization = 1.00 | pJ/Compute =  281.965 | L5[WIO] M5 C75 P55 - L4[I] M5 S3 N16X - L3[] M3 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  5] Utilization = 1.00 | pJ/Compute =  107.664 | L5[WIO] M3 C75 P55 - L4[] S3 N16X - L3[O] M25 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  3] Utilization = 1.00 | pJ/Compute =  274.197 | L5[WIO] M5 C75 P55 - L4[WI] M5 S3 N16X - L3[] M3 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  5] Utilization = 1.00 | pJ/Compute =   99.896 | L5[WIO] M3 C75 P55 - L4[W] S3 N16X - L3[O] M25 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  3] Utilization = 1.00 | pJ/Compute =  145.497 | L5[WIO] M5 C75 P55 - L4[] M5 S3 N16X - L3[O] M3 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  3] Utilization = 1.00 | pJ/Compute =  137.728 | L5[WIO] M5 C75 P55 - L4[W] M5 S3 N16X - L3[O] M3 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  3] Utilization = 1.00 | pJ/Compute =  111.919 | L5[WIO] M5 C75 P55 - L4[I] M5 S3 N16X - L3[O] M3 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  6] Utilization = 1.00 | pJ/Compute =  275.053 | L5[WIO] C75 P55 - L4[I] M25 S3 N16X - L3[] M3 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  3] Utilization = 1.00 | pJ/Compute =  104.150 | L5[WIO] M5 C75 P55 - L4[WI] M5 S3 N16X - L3[O] M3 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  6] Utilization = 1.00 | pJ/Compute =  267.284 | L5[WIO] C75 P55 - L4[WI] M25 S3 N16X - L3[] M3 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  1] Utilization = 1.00 | pJ/Compute =  281.150 | L5[WIO] M5 C75 P55 - L4[] S3 N16X - L3[] M15 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  1] Utilization = 1.00 | pJ/Compute =  273.381 | L5[WIO] M5 C75 P55 - L4[W] S3 N16X - L3[] M15 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  7] Utilization = 1.00 | pJ/Compute =  315.543 | L5[WIO] M25 C75 P55 - L4[] S3 N16X - L3[] M3 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  6] Utilization = 1.00 | pJ/Compute =  145.497 | L5[WIO] C75 P55 - L4[] M25 S3 N16X - L3[O] M3 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  7] Utilization = 1.00 | pJ/Compute =  307.775 | L5[WIO] M25 C75 P55 - L4[W] S3 N16X - L3[] M3 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  6] Utilization = 1.00 | pJ/Compute =  137.728 | L5[WIO] C75 P55 - L4[W] M25 S3 N16X - L3[O] M3 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  6] Utilization = 1.00 | pJ/Compute =  105.007 | L5[WIO] C75 P55 - L4[I] M25 S3 N16X - L3[O] M3 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  6] Utilization = 1.00 | pJ/Compute =   97.238 | L5[WIO] C75 P55 - L4[WI] M25 S3 N16X - L3[O] M3 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  7] Utilization = 1.00 | pJ/Compute =  145.497 | L5[WIO] M25 C75 P55 - L4[] S3 N16X - L3[O] M3 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  1] Utilization = 1.00 | pJ/Compute =  111.104 | L5[WIO] M5 C75 P55 - L4[] S3 N16X - L3[O] M15 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  1] Utilization = 1.00 | pJ/Compute =  103.335 | L5[WIO] M5 C75 P55 - L4[W] S3 N16X - L3[O] M15 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  5] Utilization = 1.00 | pJ/Compute =   23.381 | L5[WIO] M3 P55 C75 - L4[] S3 N16X - L3[O] M25 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  7] Utilization = 1.00 | pJ/Compute =  137.728 | L5[WIO] M25 C75 P55 - L4[W] S3 N16X - L3[O] M3 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  4] Utilization = 1.00 | pJ/Compute =  298.347 | L5[WIO] C75 P55 - L4[] M15 S3 N16X - L3[] M5 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  4] Utilization = 1.00 | pJ/Compute =  290.578 | L5[WIO] C75 P55 - L4[W] M15 S3 N16X - L3[] M5 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  4] Utilization = 1.00 | pJ/Compute =  274.744 | L5[WIO] C75 P55 - L4[I] M15 S3 N16X - L3[] M5 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  4] Utilization = 1.00 | pJ/Compute =  266.975 | L5[WIO] C75 P55 - L4[WI] M15 S3 N16X - L3[] M5 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  4] Utilization = 1.00 | pJ/Compute =  128.300 | L5[WIO] C75 P55 - L4[] M15 S3 N16X - L3[O] M5 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  4] Utilization = 1.00 | pJ/Compute =  120.532 | L5[WIO] C75 P55 - L4[W] M15 S3 N16X - L3[O] M5 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  4] Utilization = 1.00 | pJ/Compute =  104.697 | L5[WIO] C75 P55 - L4[I] M15 S3 N16X - L3[O] M5 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  4] Utilization = 1.00 | pJ/Compute =   96.929 | L5[WIO] C75 P55 - L4[WI] M15 S3 N16X - L3[O] M5 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  2] Utilization = 1.00 | pJ/Compute =   46.441 | L5[WIO] M3 P55 C75 - L4[O] M5 S3 N16X - L3[] M5 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  2] Utilization = 1.00 | pJ/Compute =   26.294 | L5[WIO] M3 P55 C75 - L4[IO] M5 S3 N16X - L3[] M5 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  1] Utilization = 1.00 | pJ/Compute =   26.821 | L5[WIO] M5 P55 C75 - L4[] S3 N16X - L3[O] M15 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  2] Utilization = 1.00 | pJ/Compute =   24.945 | L5[WIO] M3 P55 C75 - L4[IO] M5 S3 N16X - L3[O] M5 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  3] Utilization = 1.00 | pJ/Compute =   63.638 | L5[WIO] M5 P55 C75 - L4[O] M5 S3 N16X - L3[] M3 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  3] Utilization = 1.00 | pJ/Compute =   30.060 | L5[WIO] M5 P55 C75 - L4[IO] M5 S3 N16X - L3[] M3 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  3] Utilization = 1.00 | pJ/Compute =   28.710 | L5[WIO] M5 P55 C75 - L4[IO] M5 S3 N16X - L3[O] M3 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  7] Utilization = 1.00 | pJ/Compute =   61.214 | L5[WIO] M25 P55 C75 - L4[] S3 N16X - L3[O] M3 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  0] STATEMENT: 1500 invalid mappings (1323 fanout, 177 capacity) found since the last valid mapping, terminating search.
# [  6] Utilization = 1.00 | pJ/Compute =   46.441 | L5[WIO] M5 P55 C75 - L4[O] M3 S3 N16X - L3[] M5 - L2[W] N1 - L1[I] N1 - L0[O] N1
# ...
# Warning: neither block size nor cluster size specified, set according to specified storage width: block size: 1  cluster-size: 1
# Warning: neither block size nor cluster size specified, set according to specified storage width: block size: 1  cluster-size: 1
# Warning: neither block size nor cluster size specified, set according to specified storage width: block size: 1  cluster-size: 1
# execute:/usr/local/bin/accelergy tmp.yaml --oprefix timeloop-mapper. -o ./ > timeloop-mapper.accelergy.log 2>&1
# Generate Accelergy ERT (energy reference table) to replace internal energy model.
# Generate Accelergy ART (area reference table) to replace internal area model.
# Architecture configuration complete.
# Sparse optimization configuration complete.
# Using threads = 8
# Mapper configuration complete.
# Initializing Index Factorization subspace.
#   Factorization options along problem dimension R = 1
#   Factorization options along problem dimension S = 1
#   Factorization options along problem dimension T = 1
#   Factorization options along problem dimension P = 1
#   Factorization options along problem dimension Q = 1
#   Factorization options along problem dimension F = 1
#   Factorization options along problem dimension C = 1
#   Factorization options along problem dimension M = 196
#   Factorization options along problem dimension N = 1
# Mapspace Dimension [IndexFactorization] Size: 196
# Mapspace Dimension [LoopPermutation] Size: 6292383221978976013516800000
# Mapspace Dimension [Spatial] Size: 10
# Mapspace Dimension [DatatypeBypass] Size: 64
# Mapspace split! Per-split Mapping Dimension [IndexFactorization] Size: 25 Residue: 4
# Mapspace construction complete.
# Search configuration complete.
# WARNING: no optimization metric(s) specified, using edp as default.
# WARNING: Interpreting 0 to mean full problem dimension instead of residue.
# WARNING: Interpreting 0 to mean full problem dimension instead of residue.
# WARNING: Interpreting 0 to mean full problem dimension instead of residue.
# WARNING: Interpreting 0 to mean full problem dimension instead of residue.
# WARNING: Interpreting 0 to mean full problem dimension instead of residue.
# WARNING: Interpreting 0 to mean full problem dimension instead of residue.
# WARNING: Interpreting 0 to mean full problem dimension instead of residue.
# [  2] Utilization = 1.00 | pJ/Compute =  298.060 | L5[WIO] M3 C75 P28 - L4[] M5 S2 N16X - L3[] M5 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  6] Utilization = 1.00 | pJ/Compute =  315.257 | L5[WIO] C75 P28 - L4[] M25 S2 N16X - L3[] M3 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  2] Utilization = 1.00 | pJ/Compute =  290.433 | L5[WIO] M3 C75 P28 - L4[W] M5 S2 N16X - L3[] M5 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  2] Utilization = 1.00 | pJ/Compute =  277.913 | L5[WIO] M3 C75 P28 - L4[I] M5 S2 N16X - L3[] M5 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  2] Utilization = 1.00 | pJ/Compute =  270.287 | L5[WIO] M3 C75 P28 - L4[WI] M5 S2 N16X - L3[] M5 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  5] Utilization = 1.00 | pJ/Compute =  277.424 | L5[WIO] M3 C75 P28 - L4[] S2 N16X - L3[] M25 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  5] Utilization = 1.00 | pJ/Compute =  269.797 | L5[WIO] M3 C75 P28 - L4[W] S2 N16X - L3[] M25 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  7] Utilization = 1.00 | pJ/Compute =  315.257 | L5[WIO] M25 C75 P28 - L4[] S2 N16X - L3[] M3 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  2] Utilization = 1.00 | pJ/Compute =  170.724 | L5[WIO] M3 C75 P28 - L4[] M5 S2 N16X - L3[O] M5 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  7] Utilization = 1.00 | pJ/Compute =  307.630 | L5[WIO] M25 C75 P28 - L4[W] S2 N16X - L3[] M3 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  2] Utilization = 1.00 | pJ/Compute =  163.098 | L5[WIO] M3 C75 P28 - L4[W] M5 S2 N16X - L3[O] M5 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  2] Utilization = 1.00 | pJ/Compute =  150.578 | L5[WIO] M3 C75 P28 - L4[I] M5 S2 N16X - L3[O] M5 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  2] Utilization = 1.00 | pJ/Compute =  142.951 | L5[WIO] M3 C75 P28 - L4[WI] M5 S2 N16X - L3[O] M5 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  6] Utilization = 1.00 | pJ/Compute =  307.630 | L5[WIO] C75 P28 - L4[W] M25 S2 N16X - L3[] M3 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  5] Utilization = 1.00 | pJ/Compute =  150.088 | L5[WIO] M3 C75 P28 - L4[] S2 N16X - L3[O] M25 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  5] Utilization = 1.00 | pJ/Compute =  142.462 | L5[WIO] M3 C75 P28 - L4[W] S2 N16X - L3[O] M25 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  6] Utilization = 1.00 | pJ/Compute =  274.766 | L5[WIO] C75 P28 - L4[I] M25 S2 N16X - L3[] M3 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  6] Utilization = 1.00 | pJ/Compute =  267.140 | L5[WIO] C75 P28 - L4[WI] M25 S2 N16X - L3[] M3 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  6] Utilization = 1.00 | pJ/Compute =  187.921 | L5[WIO] C75 P28 - L4[] M25 S2 N16X - L3[O] M3 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  6] Utilization = 1.00 | pJ/Compute =  180.294 | L5[WIO] C75 P28 - L4[W] M25 S2 N16X - L3[O] M3 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  1] Utilization = 1.00 | pJ/Compute =  280.863 | L5[WIO] M5 C75 P28 - L4[] S2 N16X - L3[] M15 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  1] Utilization = 1.00 | pJ/Compute =  273.237 | L5[WIO] M5 C75 P28 - L4[W] S2 N16X - L3[] M15 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  1] Utilization = 1.00 | pJ/Compute =  153.528 | L5[WIO] M5 C75 P28 - L4[] S2 N16X - L3[O] M15 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  1] Utilization = 1.00 | pJ/Compute =  145.901 | L5[WIO] M5 C75 P28 - L4[W] S2 N16X - L3[O] M15 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  3] Utilization = 1.00 | pJ/Compute =  315.257 | L5[WIO] M5 C75 P28 - L4[] M5 S2 N16X - L3[] M3 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  4] Utilization = 1.00 | pJ/Compute =  298.060 | L5[WIO] C75 P28 - L4[] M15 S2 N16X - L3[] M5 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  4] Utilization = 1.00 | pJ/Compute =  290.433 | L5[WIO] C75 P28 - L4[W] M15 S2 N16X - L3[] M5 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  6] Utilization = 1.00 | pJ/Compute =  147.430 | L5[WIO] C75 P28 - L4[I] M25 S2 N16X - L3[O] M3 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  6] Utilization = 1.00 | pJ/Compute =  139.804 | L5[WIO] C75 P28 - L4[WI] M25 S2 N16X - L3[O] M3 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  4] Utilization = 1.00 | pJ/Compute =  274.457 | L5[WIO] C75 P28 - L4[I] M15 S2 N16X - L3[] M5 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  4] Utilization = 1.00 | pJ/Compute =  266.830 | L5[WIO] C75 P28 - L4[WI] M15 S2 N16X - L3[] M5 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  7] Utilization = 1.00 | pJ/Compute =  187.921 | L5[WIO] M25 C75 P28 - L4[] S2 N16X - L3[O] M3 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  7] Utilization = 1.00 | pJ/Compute =  180.294 | L5[WIO] M25 C75 P28 - L4[W] S2 N16X - L3[O] M3 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  3] Utilization = 1.00 | pJ/Compute =  307.630 | L5[WIO] M5 C75 P28 - L4[W] M5 S2 N16X - L3[] M3 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  4] Utilization = 1.00 | pJ/Compute =  170.724 | L5[WIO] C75 P28 - L4[] M15 S2 N16X - L3[O] M5 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  3] Utilization = 1.00 | pJ/Compute =  281.679 | L5[WIO] M5 C75 P28 - L4[I] M5 S2 N16X - L3[] M3 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  3] Utilization = 1.00 | pJ/Compute =  274.052 | L5[WIO] M5 C75 P28 - L4[WI] M5 S2 N16X - L3[] M3 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  4] Utilization = 1.00 | pJ/Compute =  163.098 | L5[WIO] C75 P28 - L4[W] M15 S2 N16X - L3[O] M5 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  3] Utilization = 1.00 | pJ/Compute =  187.921 | L5[WIO] M5 C75 P28 - L4[] M5 S2 N16X - L3[O] M3 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  5] Utilization = 1.00 | pJ/Compute =   23.663 | L5[WIO] M3 P28 C75 - L4[] S2 N16X - L3[O] M25 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  4] Utilization = 1.00 | pJ/Compute =  147.121 | L5[WIO] C75 P28 - L4[I] M15 S2 N16X - L3[O] M5 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  3] Utilization = 1.00 | pJ/Compute =  180.294 | L5[WIO] M5 C75 P28 - L4[W] M5 S2 N16X - L3[O] M3 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  4] Utilization = 1.00 | pJ/Compute =  139.495 | L5[WIO] C75 P28 - L4[WI] M15 S2 N16X - L3[O] M5 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  3] Utilization = 1.00 | pJ/Compute =  154.343 | L5[WIO] M5 C75 P28 - L4[I] M5 S2 N16X - L3[O] M3 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  3] Utilization = 1.00 | pJ/Compute =  146.716 | L5[WIO] M5 C75 P28 - L4[WI] M5 S2 N16X - L3[O] M3 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  1] Utilization = 1.00 | pJ/Compute =   27.103 | L5[WIO] M5 P28 C75 - L4[] S2 N16X - L3[O] M15 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  2] Utilization = 1.00 | pJ/Compute =   46.724 | L5[WIO] M3 P28 C75 - L4[O] M5 S2 N16X - L3[] M5 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  2] Utilization = 1.00 | pJ/Compute =   26.577 | L5[WIO] M3 P28 C75 - L4[IO] M5 S2 N16X - L3[] M5 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  2] Utilization = 1.00 | pJ/Compute =   25.764 | L5[WIO] M3 P28 C75 - L4[IO] M5 S2 N16X - L3[O] M5 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  7] Utilization = 1.00 | pJ/Compute =   61.496 | L5[WIO] M25 P28 C75 - L4[] S2 N16X - L3[O] M3 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  0] STATEMENT: 1500 invalid mappings (1323 fanout, 177 capacity) found since the last valid mapping, terminating search.
# [  3] Utilization = 1.00 | pJ/Compute =   63.921 | L5[WIO] M5 P28 C75 - L4[O] M5 S2 N16X - L3[] M3 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  3] Utilization = 1.00 | pJ/Compute =   30.343 | L5[WIO] M5 P28 C75 - L4[IO] M5 S2 N16X - L3[] M3 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  3] Utilization = 1.00 | pJ/Compute =   29.529 | L5[WIO] M5 P28 C75 - L4[IO] M5 S2 N16X - L3[O] M3 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  3] Utilization = 1.00 | pJ/Compute =   29.527 | L5[WIO] M5 P28 C75 - L4[O] S2 M5 N16X - L3[] M3 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  6] Utilization = 1.00 | pJ/Compute =   46.724 | L5[WIO] M5 P28 C75 - L4[O] M3 S2 N16X - L3[] M5 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  6] Utilization = 1.00 | pJ/Compute =   30.034 | L5[WIO] M5 P28 C75 - L4[IO] M3 S2 N16X - L3[] M5 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  6] Utilization = 1.00 | pJ/Compute =   29.220 | L5[WIO] M5 P28 C75 - L4[IO] M3 S2 N16X - L3[O] M5 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  6] Utilization = 1.00 | pJ/Compute =   26.467 | L5[WIO] M3 P28 C75 - L4[IO] M25 S2 N16X - L3[] N1 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  6] Utilization = 1.00 | pJ/Compute =   26.088 | L5[WIO] M3 P28 C75 - L4[O] S2 M25 N16X - L3[] N1 - L2[W] N1 - L1[I] N1 - L0[O] N1
# [  4] STATEMENT: 800 suboptimal mappings found since the last upgrade, terminating search.
# [  7] STATEMENT: 800 suboptimal mappings found since the last upgrade, terminating search.
# [  2] STATEMENT: 800 suboptimal mappings found since the last upgrade, terminating search.
# [  5] STATEMENT: 800 suboptimal mappings found since the last upgrade, terminating search.
# [  3] STATEMENT: 800 suboptimal mappings found since the last upgrade, terminating search.
# [  1] STATEMENT: 800 suboptimal mappings found since the last upgrade, terminating search.
# [  6] STATEMENT: 800 suboptimal mappings found since the last upgrade, terminating search.
# Summary stats for best mapping found by mapper:
#   Utilization = 1.00 | pJ/Compute =   23.663
# 119.26 5040000 315000
# HERE: designs/system_manual/arch/system_arch_1x16.yaml designs/system_manual/arch/components _layers/layer_shape_6.yaml _layers/map_6.yaml designs/system_auto/mapper/mapper.yaml
# input file: tmp.yaml
#   _______                __
#  /_  __(_)___ ___  ___  / /___  ____  ____
#   / / / / __ `__ \/ _ \/ / __ \/ __ \/ __ \
#  / / / / / / / / /  __/ / /_/ / /_/ / /_/ /
# /_/ /_/_/ /_/ /_/\___/_/\____/\____/ .___/
#                                   /_/
#
# Problem configuration complete.
# Warning: neither block size nor cluster size specified, set according to specified storage width: block size: 1  cluster-size: 1
# Warning: neither block size nor cluster size specified, set according to specified storage width: block size: 1  cluster-size: 1
# Warning: neither block size nor cluster size specified, set according to specified storage width: block size: 1  cluster-size: 1
# Warning: neither block size nor cluster size specified, set according to specified storage width: block size: 1  cluster-size: 1
# Warning: neither block size nor cluster size specified, set according to specified storage width: block size: 1  cluster-size: 1
# execute:/usr/local/bin/accelergy tmp.yaml --oprefix timeloop-mapper. -o ./ > timeloop-mapper.accelergy.log 2>&1
# Generate Accelergy ERT (energy reference table) to replace internal energy model.
# Generate Accelergy ART (area reference table) to replace internal area model.
# Architecture configuration complete.
# Sparse optimization configuration complete.
# Using threads = 8
# Mapper configuration complete.
# Initializing Index Factorization subspace.
#   Factorization options along problem dimension N = 1
#   Factorization options along problem dimension I = 38416
#   Factorization options along problem dimension O = 210
# Mapspace Dimension [IndexFactorization] Size: 8067360
# Mapspace Dimension [LoopPermutation] Size: 7776
# Mapspace Dimension [Spatial] Size: 4
# Mapspace Dimension [DatatypeBypass] Size: 64
# Mapspace split! Per-split Mapping Dimension [IndexFactorization] Size: 1008420 Residue: 0
# Mapspace construction complete.
# Search configuration complete.
# WARNING: no optimization metric(s) specified, using edp as default.
# [  0] STATEMENT: 1500 invalid mappings (1451 fanout, 49 capacity) found since the last valid mapping, terminating search.
# [  2] Utilization = 1.00 | pJ/Compute =  155.342 | L5[WIO] O8 I84 - L4[] O1 N16X - L3[] O2 I25 - L2[W] O1 - L1[I] O1 - L0[O] O1
# [  2] Utilization = 1.00 | pJ/Compute =   91.742 | L5[WIO] O8 I84 - L4[] O1 N16X - L3[I] O2 I25 - L2[W] O1 - L1[I] O1 - L0[O] O1
# [  3] Utilization = 1.00 | pJ/Compute =  150.203 | L5[WIO] O2 I14 - L4[] O4 I3 N16X - L3[] O2 I50 - L2[W] O1 - L1[I] O1 - L0[O] O1
# [  2] Utilization = 1.00 | pJ/Compute =   81.645 | L5[WIO] O8 I84 - L4[] O1 N16X - L3[IO] O2 I25 - L2[W] O1 - L1[I] O1 - L0[O] O1
# [  3] Utilization = 1.00 | pJ/Compute =  146.802 | L5[WIO] O2 I14 - L4[] O4 I3 N16X - L3[O] O2 I50 - L2[W] O1 - L1[I] O1 - L0[O] O1
# [  3] Utilization = 1.00 | pJ/Compute =  145.264 | L5[WIO] O2 I14 - L4[O] O4 I3 N16X - L3[] O2 I50 - L2[W] O1 - L1[I] O1 - L0[O] O1
# [  3] Utilization = 1.00 | pJ/Compute =  145.237 | L5[WIO] O2 I14 - L4[O] O4 I3 N16X - L3[O] O2 I50 - L2[W] O1 - L1[I] O1 - L0[O] O1
# [  6] STATEMENT: 1500 invalid mappings (1448 fanout, 52 capacity) found since the last valid mapping, terminating search.
# [  3] Utilization = 1.00 | pJ/Compute =   83.792 | L5[WIO] O2 I14 - L4[] O4 I3 N16X - L3[O] I50 O2 - L2[W] O1 - L1[I] O1 - L0[O] O1
# [  3] Utilization = 1.00 | pJ/Compute =   82.227 | L5[WIO] O2 I14 - L4[O] O4 I3 N16X - L3[O] I50 O2 - L2[W] O1 - L1[I] O1 - L0[O] O1
# [  1] STATEMENT: 1500 invalid mappings (1452 fanout, 48 capacity) found since the last valid mapping, terminating search.
# [  7] STATEMENT: 1500 invalid mappings (1448 fanout, 52 capacity) found since the last valid mapping, terminating search.
# [  5] STATEMENT: 1500 invalid mappings (1447 fanout, 53 capacity) found since the last valid mapping, terminating search.
# [  4] STATEMENT: 1500 invalid mappings (1447 fanout, 53 capacity) found since the last valid mapping, terminating search.
# [  2] Utilization = 1.00 | pJ/Compute =   35.625 | L5[WIO] I84 O8 - L4[] O1 N16X - L3[I] O2 I25 - L2[W] O1 - L1[I] O1 - L0[O] O1
# [  3] STATEMENT: 1500 invalid mappings (1447 fanout, 53 capacity) found since the last valid mapping, terminating search.
# [  2] STATEMENT: 1500 invalid mappings (1445 fanout, 55 capacity) found since the last valid mapping, terminating search.
# Summary stats for best mapping found by mapper:
#   Utilization = 1.00 | pJ/Compute =   35.625
# 19.15 537600 33600
# layer types: ['conv3d', 'conv3d', 'conv3d', 'conv3d', 'conv3d', 'conv3d', 'linear']
# energy: 3400.11 (layerwise: [419.96, 519.12, 1628.2, 347.21, 347.21, 119.26, 19.15])
# mac: 141696480 (layerwise: [16951680, 18835200, 70632000, 14850000, 14850000, 5040000, 537600])
# param: 120840 (layerwise: [540, 1200, 40500, 16875, 16875, 11250, 33600])
# cycle: 8856030 (layerwise: [1059480, 1177200, 4414500, 928125, 928125, 315000, 33600])

# %%
class HamidaEtAl2d(nn.Module):
    """
    3-D Deep Learning Approach for Remote Sensing Image Classification
    Amina Ben Hamida, Alexandre Benoit, Patrick Lambert, Chokri Ben Amar
    IEEE TGRS, 2018
    https://ieeexplore.ieee.org/stamp/stamp.jsp?arnumber=8344565
    """
    @staticmethod
    def weight_init(m):
        if isinstance(m, nn.Linear) or isinstance(m, nn.Conv2d):
            init.kaiming_normal_(m.weight)
            init.zeros_(m.bias)

    def __init__(self, input_channels, n_classes, patch_size=5, dilation=1):
        super(HamidaEtAl2d, self).__init__()
        # The first layer is a (3,3,3) kernel sized Conv characterized
        # by a stride equal to 1 and number of neurons equal to 20
        self.patch_size = patch_size
        self.input_channels = input_channels
        # dilation = (dil)

        if patch_size == 3:
            self.conv1 = nn.Conv2d(
                200, 20, (3, 3), stride=(1, 1), dilation=dilation, padding=1)
        else:
            self.conv1 = nn.Conv2d(
                200, 20, (3, 3), stride=(1, 1), dilation=dilation, padding=0)
        # Next pooling is applied using a layer identical to the previous one
        # with the difference of a 1D kernel size (1,1,3) and a larger stride
        # equal to 2 in order to reduce the spectral dimension
        self.pool1 = nn.Conv2d(
            20, 100, (3, 1), dilation=dilation, stride=(2, 1), padding=(1, 0))
        # Then, a duplicate of the first and second layers is created with
        # 35 hidden neurons per layer.
        self.conv2 = nn.Conv2d(
            100, 500, (3, 3), dilation=dilation, stride=(1, 1), padding=(1, 0))
        self.pool2 = nn.Conv2d(
            500, 500, (3, 1), dilation=dilation, stride=(2, 1), padding=(1, 0))
        # Finally, the 1D spatial dimension is progressively reduced
        # thanks to the use of two Conv layers, 35 neurons each,
        # with respective kernel sizes of (1,1,3) and (1,1,2) and strides
        # respectively equal texo (1,1,1) and (1,1,2)
        self.conv3 = nn.Conv2d(
            500, 800, (3, 1), dilation=dilation, stride=(1, 1), padding=(1, 0))
        self.conv4 = nn.Conv2d(
            800, 1000, (2, 1), dilation=dilation, stride=(2, 1), padding=(1, 0))

        #self.dropout = nn.Dropout(p=0.5)

        self.features_size = self._get_final_flattened_size()
        # The architecture ends with a fully connected layer where the number
        # of neurons is equal to the number of input classes.
        self.fc = nn.Linear(self.features_size, n_classes)

        # self.apply(self.weight_init)

    def _get_final_flattened_size(self):

        with torch.no_grad():
            x = torch.zeros((1, self.input_channels,
                             self.patch_size, self.patch_size))
            x = self.pool1(self.conv1(x))
            x = self.pool2(self.conv2(x))
            x = self.conv3(x)
            x = self.conv4(x)
            print(x.shape)
            _, c, w, h = x.size()
        return  c * w * h

    def forward(self, x):
        x = x.squeeze()

        x = F.relu(self.conv1(x))

        x = self.pool1(x)
        x = F.relu(self.conv2(x))
        x = self.pool2(x)
        x = F.relu(self.conv3(x))
        x = F.relu(self.conv4(x))
        x = x.view(-1, self.features_size)
        #x = self.dropout(x)
        x = self.fc(x)
        return x

# %%
# Hamida 2D
model = HamidaEtAl2d(input_channels=200, n_classes=16)
x = torch.rand(16, 200, 5, 5)

types, energy, l_energy, mac, l_mac, param, l_param, cycle, l_cycle = get_energy(model, x, verbose=False)
print("layer types:", types)
print("energy:", energy, f"(layerwise: {l_energy})")
print("mac:", mac, f"(layerwise: {l_mac})")
print("param:", param, f"(layerwise: {l_param})")
print("cycle:", cycle, f"(layerwise: {l_cycle})")
# Out:
# torch.Size([1, 1000, 1, 1])
# HERE: designs/system_manual/arch/system_arch_1x16.yaml designs/system_manual/arch/components _layers/layer_shape_0.yaml _layers/map_0.yaml designs/system_auto/mapper/mapper.yaml
# input file: tmp.yaml
#   _______                __
#  /_  __(_)___ ___  ___  / /___  ____  ____
#   / / / / __ `__ \/ _ \/ / __ \/ __ \/ __ \
#  / / / / / / / / /  __/ / /_/ / /_/ / /_/ /
# /_/ /_/_/ /_/ /_/\___/_/\____/\____/ .___/
#                                   /_/
#
# Problem configuration complete.
# Warning: neither block size nor cluster size specified, set according to specified storage width: block size: 1  cluster-size: 1
# Warning: neither block size nor cluster size specified, set according to specified storage width: block size: 1  cluster-size: 1
# Warning: neither block size nor cluster size specified, set according to specified storage width: block size: 1  cluster-size: 1
# Warning: neither block size nor cluster size specified, set according to specified storage width: block size: 1  cluster-size: 1
# Warning: neither block size nor cluster size specified, set according to specified storage width: block size: 1  cluster-size: 1
# execute:/usr/local/bin/accelergy tmp.yaml --oprefix timeloop-mapper. -o ./ > timeloop-mapper.accelergy.log 2>&1
# Generate Accelergy ERT (energy reference table) to replace internal energy model.
# Generate Accelergy ART (area reference table) to replace internal area model.
# Architecture configuration complete.
# Sparse optimization configuration complete.
# Using threads = 8
# Mapper configuration complete.
# Initializing Index Factorization subspace.
#   Factorization options along problem dimension C = 1
#   Factorization options along problem dimension M = 196
#   Factorization options along problem dimension R = 7
#   Factorization options along problem dimension S = 7
#   Factorization options along problem dimension N = 1
#   Factorization options along problem dimension P = 7
#   Factorization options along problem dimension Q = 7
# Mapspace Dimension [IndexFactorization] Size: 470596
# Mapspace Dimension [LoopPermutation] Size: 3252016064102400000
# Mapspace Dimension [Spatial] Size: 8
# Mapspace Dimension [DatatypeBypass] Size: 64
# Mapspace split! Per-split Mapping Dimension [IndexFactorization] Size: 58825 Residue: 4
# Mapspace construction complete.
# Search configuration complete.
# WARNING: no optimization metric(s) specified, using edp as default.
# WARNING: Interpreting 0 to mean full problem dimension instead of residue.
# [  4] Utilization = 1.00 | pJ/Compute =  337.541 | L5[WIO] Q3 P3 R3 C200 - L4[] M10 N16X - L3[] S3 M2 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  4] Utilization = 1.00 | pJ/Compute =  280.087 | L5[WIO] Q3 P3 R3 C200 - L4[] M10 N16X - L3[I] S3 M2 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  4] Utilization = 1.00 | pJ/Compute =  167.495 | L5[WIO] Q3 P3 R3 C200 - L4[] M10 N16X - L3[O] S3 M2 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  4] Utilization = 1.00 | pJ/Compute =  110.042 | L5[WIO] Q3 P3 R3 C200 - L4[] M10 N16X - L3[IO] S3 M2 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  4] Utilization = 1.00 | pJ/Compute =   84.639 | L5[WIO] Q3 P3 R3 C200 - L4[O] M10 N16X - L3[] S3 M2 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  4] Utilization = 1.00 | pJ/Compute =   27.185 | L5[WIO] Q3 P3 R3 C200 - L4[O] M10 N16X - L3[I] S3 M2 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  2] Utilization = 1.00 | pJ/Compute =  396.045 | L5[WIO] Q3 C200 - L4[] S3 N16X - L3[] R3 M20 - L2[W] P3 - L1[I] Q1 - L0[O] Q1
# [  4] Utilization = 1.00 | pJ/Compute =   25.836 | L5[WIO] Q3 P3 R3 C200 - L4[O] M10 N16X - L3[IO] S3 M2 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  2] Utilization = 1.00 | pJ/Compute =  271.874 | L5[WIO] Q3 C200 - L4[] S3 N16X - L3[I] R3 M20 - L2[W] P3 - L1[I] Q1 - L0[O] Q1
# [  2] Utilization = 1.00 | pJ/Compute =  270.136 | L5[WIO] C200 Q3 - L4[W] S3 N16X - L3[I] R3 M20 - L2[W] P3 - L1[I] Q1 - L0[O] Q1
# [  2] Utilization = 1.00 | pJ/Compute =  269.650 | L5[WIO] C200 Q3 - L4[WI] S3 N16X - L3[] R3 M20 - L2[W] P3 - L1[I] Q1 - L0[O] Q1
# [  1] STATEMENT: 1500 invalid mappings (1457 fanout, 43 capacity) found since the last valid mapping, terminating search.
# [  2] Utilization = 1.00 | pJ/Compute =  268.618 | L5[WIO] C200 Q3 - L4[WI] S3 N16X - L3[I] R3 M20 - L2[W] P3 - L1[I] Q1 - L0[O] Q1
# [  0] STATEMENT: 1500 invalid mappings (1456 fanout, 44 capacity) found since the last valid mapping, terminating search.
# [  7] STATEMENT: 1500 invalid mappings (1455 fanout, 45 capacity) found since the last valid mapping, terminating search.
# [  3] Utilization = 1.00 | pJ/Compute =  396.045 | L5[WIO] R3 C200 - L4[] Q3 M20 N16X - L3[] S3 - L2[W] P3 - L1[I] Q1 - L0[O] Q1
# [  3] Utilization = 1.00 | pJ/Compute =  394.306 | L5[WIO] R3 C200 - L4[W] Q3 M20 N16X - L3[] S3 - L2[W] P3 - L1[I] Q1 - L0[O] Q1
# [  3] Utilization = 1.00 | pJ/Compute =  274.725 | L5[WIO] R3 C200 - L4[] Q3 M20 N16X - L3[I] S3 - L2[W] P3 - L1[I] Q1 - L0[O] Q1
# [  3] Utilization = 1.00 | pJ/Compute =  272.986 | L5[WIO] R3 C200 - L4[W] Q3 M20 N16X - L3[I] S3 - L2[W] P3 - L1[I] Q1 - L0[O] Q1
# [  3] Utilization = 1.00 | pJ/Compute =  271.251 | L5[WIO] R3 C200 - L4[WI] Q3 M20 N16X - L3[] S3 - L2[W] P3 - L1[I] Q1 - L0[O] Q1
# [  3] Utilization = 1.00 | pJ/Compute =  270.254 | L5[WIO] R3 C200 - L4[WI] Q3 M20 N16X - L3[I] S3 - L2[W] P3 - L1[I] Q1 - L0[O] Q1
# [  3] Utilization = 1.00 | pJ/Compute =  226.000 | L5[WIO] R3 C200 - L4[] Q3 M20 N16X - L3[O] S3 - L2[W] P3 - L1[I] Q1 - L0[O] Q1
# [  3] Utilization = 1.00 | pJ/Compute =  224.261 | L5[WIO] R3 C200 - L4[W] Q3 M20 N16X - L3[O] S3 - L2[W] P3 - L1[I] Q1 - L0[O] Q1
# [  3] Utilization = 1.00 | pJ/Compute =  104.679 | L5[WIO] R3 C200 - L4[] Q3 M20 N16X - L3[IO] S3 - L2[W] P3 - L1[I] Q1 - L0[O] Q1
# [  3] Utilization = 1.00 | pJ/Compute =  102.941 | L5[WIO] R3 C200 - L4[W] Q3 M20 N16X - L3[IO] S3 - L2[W] P3 - L1[I] Q1 - L0[O] Q1
# [  3] Utilization = 1.00 | pJ/Compute =  101.205 | L5[WIO] R3 C200 - L4[WI] Q3 M20 N16X - L3[O] S3 - L2[W] P3 - L1[I] Q1 - L0[O] Q1
# [  3] Utilization = 1.00 | pJ/Compute =  100.208 | L5[WIO] R3 C200 - L4[WI] Q3 M20 N16X - L3[IO] S3 - L2[W] P3 - L1[I] Q1 - L0[O] Q1
# [  4] Utilization = 1.00 | pJ/Compute =   25.185 | L5[WIO] Q3 P3 R3 C200 - L4[O] M10 N16X - L3[I] M2 S3 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  5] STATEMENT: 1500 invalid mappings (1465 fanout, 35 capacity) found since the last valid mapping, terminating search.
# [  6] STATEMENT: 1500 invalid mappings (1459 fanout, 41 capacity) found since the last valid mapping, terminating search.
# [  2] STATEMENT: 1500 invalid mappings (1476 fanout, 24 capacity) found since the last valid mapping, terminating search.
# [  3] Utilization = 1.00 | pJ/Compute =   99.605 | L5[WIO] C200 R3 - L4[WI] Q3 M20 N16X - L3[O] S3 - L2[W] P3 - L1[I] Q1 - L0[O] Q1
# [  3] Utilization = 1.00 | pJ/Compute =   98.608 | L5[WIO] C200 R3 - L4[WI] Q3 M20 N16X - L3[IO] S3 - L2[W] P3 - L1[I] Q1 - L0[O] Q1
# [  3] STATEMENT: 1500 invalid mappings (1476 fanout, 24 capacity) found since the last valid mapping, terminating search.
# [  4] STATEMENT: 1500 invalid mappings (1479 fanout, 21 capacity) found since the last valid mapping, terminating search.
# Summary stats for best mapping found by mapper:
#   Utilization = 1.00 | pJ/Compute =   25.185
# 130.56 5184000 324000
# HERE: designs/system_manual/arch/system_arch_1x16.yaml designs/system_manual/arch/components _layers/layer_shape_1.yaml _layers/map_1.yaml designs/system_auto/mapper/mapper.yaml
# input file: tmp.yaml
#   _______                __
#  /_  __(_)___ ___  ___  / /___  ____  ____
#   / / / / __ `__ \/ _ \/ / __ \/ __ \/ __ \
#  / / / / / / / / /  __/ / /_/ / /_/ / /_/ /
# /_/ /_/_/ /_/ /_/\___/_/\____/\____/ .___/
#                                   /_/
#
# Problem configuration complete.
# Warning: neither block size nor cluster size specified, set according to specified storage width: block size: 1  cluster-size: 1
# Warning: neither block size nor cluster size specified, set according to specified storage width: block size: 1  cluster-size: 1
# Warning: neither block size nor cluster size specified, set according to specified storage width: block size: 1  cluster-size: 1
# Warning: neither block size nor cluster size specified, set according to specified storage width: block size: 1  cluster-size: 1
# Warning: neither block size nor cluster size specified, set according to specified storage width: block size: 1  cluster-size: 1
# execute:/usr/local/bin/accelergy tmp.yaml --oprefix timeloop-mapper. -o ./ > timeloop-mapper.accelergy.log 2>&1
# Generate Accelergy ERT (energy reference table) to replace internal energy model.
# Generate Accelergy ART (area reference table) to replace internal area model.
# Architecture configuration complete.
# Sparse optimization configuration complete.
# Using threads = 8
# Mapper configuration complete.
# Initializing Index Factorization subspace.
#   Factorization options along problem dimension C = 1
#   Factorization options along problem dimension M = 784
#   Factorization options along problem dimension R = 7
#   Factorization options along problem dimension S = 1
#   Factorization options along problem dimension N = 1
#   Factorization options along problem dimension P = 7
#   Factorization options along problem dimension Q = 7
# Mapspace Dimension [IndexFactorization] Size: 268912
# Mapspace Dimension [LoopPermutation] Size: 3252016064102400000
# Mapspace Dimension [Spatial] Size: 8
# Mapspace Dimension [DatatypeBypass] Size: 64
# Mapspace split! Per-split Mapping Dimension [IndexFactorization] Size: 33614 Residue: 0
# Mapspace construction complete.
# Search configuration complete.
# WARNING: no optimization metric(s) specified, using edp as default.
# WARNING: Interpreting 0 to mean full problem dimension instead of residue.
# [  2] Utilization = 1.00 | pJ/Compute =  303.219 | L5[WIO] Q3 P2 M5 C20 - L4[] M5 N16X - L3[] R3 M4 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  2] Utilization = 1.00 | pJ/Compute =  277.699 | L5[WIO] Q3 P2 M5 C20 - L4[] M5 N16X - L3[I] R3 M4 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  2] Utilization = 1.00 | pJ/Compute =  133.170 | L5[WIO] Q3 P2 M5 C20 - L4[] M5 N16X - L3[O] R3 M4 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  2] Utilization = 1.00 | pJ/Compute =  107.649 | L5[WIO] Q3 P2 M5 C20 - L4[] M5 N16X - L3[IO] R3 M4 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  2] Utilization = 1.00 | pJ/Compute =   54.446 | L5[WIO] Q3 P2 M5 C20 - L4[O] M5 N16X - L3[] R3 M4 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  2] Utilization = 1.00 | pJ/Compute =   28.926 | L5[WIO] Q3 P2 M5 C20 - L4[O] M5 N16X - L3[I] R3 M4 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  0] Utilization = 1.00 | pJ/Compute =  228.634 | L5[WIO] M5 C20 - L4[] Q3 P2 M20 N16X - L3[] R3 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  0] Utilization = 1.00 | pJ/Compute =  222.068 | L5[WIO] M5 C20 - L4[W] Q3 P2 M20 N16X - L3[] R3 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  0] Utilization = 1.00 | pJ/Compute =  107.313 | L5[WIO] M5 C20 - L4[] Q3 P2 M20 N16X - L3[I] R3 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  0] Utilization = 1.00 | pJ/Compute =  100.747 | L5[WIO] M5 C20 - L4[W] Q3 P2 M20 N16X - L3[I] R3 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  2] Utilization = 1.00 | pJ/Compute =   27.572 | L5[WIO] Q3 P2 M5 C20 - L4[O] M5 N16X - L3[IO] R3 M4 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  0] Utilization = 1.00 | pJ/Compute =   99.815 | L5[WIO] M5 C20 - L4[WI] Q3 P2 M20 N16X - L3[I] R3 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  5] STATEMENT: 1500 invalid mappings (1440 fanout, 60 capacity) found since the last valid mapping, terminating search.
# [  1] Utilization = 1.00 | pJ/Compute =  392.471 | L5[WIO] R3 M100 C20 - L4[] Q1 N16X - L3[] Q3 - L2[W] P2 - L1[I] Q1 - L0[O] Q1
# [  7] Utilization = 1.00 | pJ/Compute =  395.463 | L5[WIO] M5 C20 - L4[] Q3 M4 N16X - L3[] R3 M5 - L2[W] P2 - L1[I] Q1 - L0[O] Q1
# [  7] Utilization = 1.00 | pJ/Compute =  392.855 | L5[WIO] M5 C20 - L4[W] Q3 M4 N16X - L3[] R3 M5 - L2[W] P2 - L1[I] Q1 - L0[O] Q1
# [  7] Utilization = 1.00 | pJ/Compute =  273.074 | L5[WIO] M5 C20 - L4[] Q3 M4 N16X - L3[I] R3 M5 - L2[W] P2 - L1[I] Q1 - L0[O] Q1
# [  7] Utilization = 1.00 | pJ/Compute =  270.466 | L5[WIO] M5 C20 - L4[W] Q3 M4 N16X - L3[I] R3 M5 - L2[W] P2 - L1[I] Q1 - L0[O] Q1
# [  3] STATEMENT: 1500 invalid mappings (1433 fanout, 67 capacity) found since the last valid mapping, terminating search.
# [  1] Utilization = 1.00 | pJ/Compute =  149.813 | L5[WIO] R3 M100 C20 - L4[] Q1 N16X - L3[O] Q3 - L2[W] P2 - L1[I] Q1 - L0[O] Q1
# [  7] Utilization = 1.00 | pJ/Compute =  225.413 | L5[WIO] M5 C20 - L4[] Q3 M4 N16X - L3[O] R3 M5 - L2[W] P2 - L1[I] Q1 - L0[O] Q1
# [  7] Utilization = 1.00 | pJ/Compute =  222.805 | L5[WIO] M5 C20 - L4[W] Q3 M4 N16X - L3[O] R3 M5 - L2[W] P2 - L1[I] Q1 - L0[O] Q1
# [  7] Utilization = 1.00 | pJ/Compute =  103.024 | L5[WIO] M5 C20 - L4[] Q3 M4 N16X - L3[IO] R3 M5 - L2[W] P2 - L1[I] Q1 - L0[O] Q1
# [  7] Utilization = 1.00 | pJ/Compute =  100.416 | L5[WIO] M5 C20 - L4[W] Q3 M4 N16X - L3[IO] R3 M5 - L2[W] P2 - L1[I] Q1 - L0[O] Q1
# [  2] Utilization = 1.00 | pJ/Compute =   27.236 | L5[WIO] Q3 P2 M5 C20 - L4[O] M5 N16X - L3[I] M4 R3 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  4] Utilization = 1.00 | pJ/Compute =  276.134 | L5[WIO] M4 C20 - L4[] Q1 N16X - L3[] Q3 P2 R3 M25 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  4] Utilization = 1.00 | pJ/Compute =  269.568 | L5[WIO] M4 C20 - L4[W] Q1 N16X - L3[] Q3 P2 R3 M25 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  4] Utilization = 1.00 | pJ/Compute =  268.735 | L5[WIO] M4 C20 - L4[W] Q1 N16X - L3[I] Q3 P2 R3 M25 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  6] STATEMENT: 1500 invalid mappings (1443 fanout, 57 capacity) found since the last valid mapping, terminating search.
# [  1] Utilization = 1.00 | pJ/Compute =  141.271 | L5[WIO] M100 R3 C20 - L4[] Q1 N16X - L3[O] Q3 - L2[W] P2 - L1[I] Q1 - L0[O] Q1
# [  4] Utilization = 1.00 | pJ/Compute =  228.634 | L5[WIO] M4 C20 - L4[] Q1 N16X - L3[] Q3 P2 M25 R3 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  4] Utilization = 1.00 | pJ/Compute =  222.068 | L5[WIO] M4 C20 - L4[W] Q1 N16X - L3[] Q3 P2 M25 R3 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  4] Utilization = 1.00 | pJ/Compute =  105.176 | L5[WIO] M4 C20 - L4[] Q1 N16X - L3[I] Q3 P2 M25 R3 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  4] Utilization = 1.00 | pJ/Compute =   98.610 | L5[WIO] M4 C20 - L4[W] Q1 N16X - L3[I] Q3 P2 M25 R3 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  7] Utilization = 1.00 | pJ/Compute =   99.837 | L5[WIO] C20 M5 - L4[I] Q3 M4 N16X - L3[O] R3 M5 - L2[W] P2 - L1[I] Q1 - L0[O] Q1
# [  7] Utilization = 1.00 | pJ/Compute =   97.229 | L5[WIO] C20 M5 - L4[WI] Q3 M4 N16X - L3[O] R3 M5 - L2[W] P2 - L1[I] Q1 - L0[O] Q1
# [  7] Utilization = 1.00 | pJ/Compute =   96.219 | L5[WIO] C20 M5 - L4[WI] Q3 M4 N16X - L3[IO] R3 M5 - L2[W] P2 - L1[I] Q1 - L0[O] Q1
# [  0] Utilization = 1.00 | pJ/Compute =   96.492 | L5[WIO] C20 M5 - L4[WI] Q3 P2 M20 N16X - L3[] R3 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  0] Utilization = 1.00 | pJ/Compute =   95.495 | L5[WIO] C20 M5 - L4[WI] Q3 P2 M20 N16X - L3[I] R3 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  1] Utilization = 1.00 | pJ/Compute =  120.426 | L5[WIO] M100 C20 R3 - L4[] Q1 N16X - L3[IO] Q3 - L2[W] P2 - L1[I] Q1 - L0[O] Q1
# [  4] Utilization = 1.00 | pJ/Compute =   95.403 | L5[WIO] C20 M4 - L4[W] Q1 N16X - L3[I] Q3 P2 M25 R3 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  0] STATEMENT: 1500 invalid mappings (1452 fanout, 48 capacity) found since the last valid mapping, terminating search.
# [  7] STATEMENT: 1500 invalid mappings (1454 fanout, 46 capacity) found since the last valid mapping, terminating search.
# [  1] Utilization = 1.00 | pJ/Compute =  101.955 | L5[WIO] Q3 M4 C20 - L4[] M5 N16X - L3[IO] R3 M5 - L2[W] P2 - L1[I] Q1 - L0[O] Q1
# [  1] Utilization = 1.00 | pJ/Compute =   98.749 | L5[WIO] Q3 C20 M4 - L4[] M5 N16X - L3[IO] R3 M5 - L2[W] P2 - L1[I] Q1 - L0[O] Q1
# [  1] Utilization = 1.00 | pJ/Compute =   98.342 | L5[WIO] C20 M100 - L4[I] P2 N16X - L3[O] R3 - L2[W] Q3 - L1[I] Q1 - L0[O] Q1
# [  1] Utilization = 1.00 | pJ/Compute =   97.141 | L5[WIO] C20 M100 - L4[I] P2 N16X - L3[WO] R3 - L2[W] Q3 - L1[I] Q1 - L0[O] Q1
# [  1] Utilization = 1.00 | pJ/Compute =   97.053 | L5[WIO] C20 M100 - L4[WI] P2 N16X - L3[O] R3 - L2[W] Q3 - L1[I] Q1 - L0[O] Q1
# [  1] Utilization = 1.00 | pJ/Compute =   47.997 | L5[WIO] M20 C20 - L4[O] Q3 P2 R3 N16X - L3[] M5 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  1] Utilization = 1.00 | pJ/Compute =   41.431 | L5[WIO] M20 C20 - L4[WO] Q3 P2 R3 N16X - L3[] M5 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  1] Utilization = 1.00 | pJ/Compute =   40.078 | L5[WIO] M20 C20 - L4[WO] Q3 P2 R3 N16X - L3[O] M5 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  4] STATEMENT: 1500 invalid mappings (1449 fanout, 51 capacity) found since the last valid mapping, terminating search.
# [  1] Utilization = 1.00 | pJ/Compute =   37.845 | L5[WIO] M20 C20 R3 - L4[O] Q1 N16X - L3[WI] Q3 M5 - L2[W] P2 - L1[I] Q1 - L0[O] Q1
# [  1] Utilization = 1.00 | pJ/Compute =   37.726 | L5[WIO] M20 C20 R3 - L4[WO] Q1 N16X - L3[I] Q3 M5 - L2[W] P2 - L1[I] Q1 - L0[O] Q1
# [  1] Utilization = 1.00 | pJ/Compute =   37.342 | L5[WIO] M20 C20 R3 - L4[O] Q1 N16X - L3[I] M5 Q3 - L2[W] P2 - L1[I] Q1 - L0[O] Q1
# [  1] STATEMENT: 1500 invalid mappings (1461 fanout, 39 capacity) found since the last valid mapping, terminating search.
# [  2] STATEMENT: 1500 invalid mappings (1437 fanout, 63 capacity) found since the last valid mapping, terminating search.
# Summary stats for best mapping found by mapper:
#   Utilization = 1.00 | pJ/Compute =   27.236
# 15.69 576000 36000
# HERE: designs/system_manual/arch/system_arch_1x16.yaml designs/system_manual/arch/components _layers/layer_shape_2.yaml _layers/map_2.yaml designs/system_auto/mapper/mapper.yaml
# input file: tmp.yaml
#   _______                __
#  /_  __(_)___ ___  ___  / /___  ____  ____
#   / / / / __ `__ \/ _ \/ / __ \/ __ \/ __ \
#  / / / / / / / / /  __/ / /_/ / /_/ / /_/ /
# /_/ /_/_/ /_/ /_/\___/_/\____/\____/ .___/
#                                   /_/
#
# Problem configuration complete.
# Warning: neither block size nor cluster size specified, set according to specified storage width: block size: 1  cluster-size: 1
# Warning: neither block size nor cluster size specified, set according to specified storage width: block size: 1  cluster-size: 1
# Warning: neither block size nor cluster size specified, set according to specified storage width: block size: 1  cluster-size: 1
# Warning: neither block size nor cluster size specified, set according to specified storage width: block size: 1  cluster-size: 1
# Warning: neither block size nor cluster size specified, set according to specified storage width: block size: 1  cluster-size: 1
# execute:/usr/local/bin/accelergy tmp.yaml --oprefix timeloop-mapper. -o ./ > timeloop-mapper.accelergy.log 2>&1
# Generate Accelergy ERT (energy reference table) to replace internal energy model.
# Generate Accelergy ART (area reference table) to replace internal area model.
# Architecture configuration complete.
# Sparse optimization configuration complete.
# Using threads = 8
# Mapper configuration complete.
# Initializing Index Factorization subspace.
#   Factorization options along problem dimension C = 1
#   Factorization options along problem dimension M = 2352
#   Factorization options along problem dimension R = 7
#   Factorization options along problem dimension S = 7
#   Factorization options along problem dimension N = 1
#   Factorization options along problem dimension P = 7
#   Factorization options along problem dimension Q = 1
# Mapspace Dimension [IndexFactorization] Size: 806736
# Mapspace Dimension [LoopPermutation] Size: 3252016064102400000
# Mapspace Dimension [Spatial] Size: 8
# Mapspace Dimension [DatatypeBypass] Size: 64
# Mapspace split! Per-split Mapping Dimension [IndexFactorization] Size: 100842 Residue: 0
# Mapspace construction complete.
# Search configuration complete.
# WARNING: no optimization metric(s) specified, using edp as default.
# WARNING: Interpreting 0 to mean full problem dimension instead of residue.
# [  5] Utilization = 1.00 | pJ/Compute =  275.561 | L5[WIO] P2 M2 C100 - L4[] R3 M5 N16X - L3[] S3 M50 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  5] Utilization = 1.00 | pJ/Compute =  273.519 | L5[WIO] P2 M2 C100 - L4[] R3 M5 N16X - L3[I] S3 M50 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  1] Utilization = 1.00 | pJ/Compute =  230.640 | L5[WIO] M20 C100 - L4[] P2 S3 M25 N16X - L3[] R3 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  1] Utilization = 1.00 | pJ/Compute =  226.774 | L5[WIO] M20 C100 - L4[W] P2 S3 M25 N16X - L3[] R3 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  1] Utilization = 1.00 | pJ/Compute =  108.037 | L5[WIO] M20 C100 - L4[] P2 S3 M25 N16X - L3[I] R3 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  1] Utilization = 1.00 | pJ/Compute =  104.171 | L5[WIO] M20 C100 - L4[W] P2 S3 M25 N16X - L3[I] R3 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  1] Utilization = 1.00 | pJ/Compute =  103.575 | L5[WIO] M20 C100 - L4[WI] P2 S3 M25 N16X - L3[] R3 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  1] Utilization = 1.00 | pJ/Compute =  102.561 | L5[WIO] M20 C100 - L4[WI] P2 S3 M25 N16X - L3[I] R3 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  5] Utilization = 1.00 | pJ/Compute =  230.640 | L5[WIO] P2 M2 C100 - L4[] R3 M5 N16X - L3[] M50 S3 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  5] Utilization = 1.00 | pJ/Compute =  103.419 | L5[WIO] P2 M2 C100 - L4[] R3 M5 N16X - L3[I] M50 S3 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  0] STATEMENT: 1500 invalid mappings (1459 fanout, 41 capacity) found since the last valid mapping, terminating search.
# [  2] STATEMENT: 1500 invalid mappings (1455 fanout, 45 capacity) found since the last valid mapping, terminating search.
# [  3] STATEMENT: 1500 invalid mappings (1453 fanout, 47 capacity) found since the last valid mapping, terminating search.
# [  1] Utilization = 1.00 | pJ/Compute =   50.335 | L5[WIO] M20 C100 - L4[I] P2 M25 S3 N16X - L3[] R3 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  1] Utilization = 1.00 | pJ/Compute =   46.469 | L5[WIO] M20 C100 - L4[WI] P2 M25 S3 N16X - L3[] R3 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  7] STATEMENT: 1500 invalid mappings (1449 fanout, 51 capacity) found since the last valid mapping, terminating search.
# [  4] STATEMENT: 1500 invalid mappings (1448 fanout, 52 capacity) found since the last valid mapping, terminating search.
# [  6] STATEMENT: 1500 invalid mappings (1450 fanout, 50 capacity) found since the last valid mapping, terminating search.
# [  5] Utilization = 1.00 | pJ/Compute =  103.172 | L5[WIO] P2 C100 M2 - L4[I] R3 M5 N16X - L3[I] M50 S3 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  5] Utilization = 1.00 | pJ/Compute =  103.171 | L5[WIO] C100 P2 M2 - L4[I] R3 M5 N16X - L3[I] M50 S3 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  5] Utilization = 1.00 | pJ/Compute =   46.589 | L5[WIO] P2 S3 M50 C100 - L4[O] M2 N16X - L3[] R3 M5 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  5] Utilization = 1.00 | pJ/Compute =   33.869 | L5[WIO] P2 S3 M50 C100 - L4[O] M2 N16X - L3[I] R3 M5 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  5] Utilization = 1.00 | pJ/Compute =   32.520 | L5[WIO] P2 S3 M50 C100 - L4[O] M2 N16X - L3[IO] R3 M5 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  1] Utilization = 1.00 | pJ/Compute =   43.185 | L5[WIO] C100 M20 - L4[WI] P2 M25 S3 N16X - L3[] R3 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  5] Utilization = 1.00 | pJ/Compute =   32.242 | L5[WIO] P2 S3 M50 C100 - L4[O] M2 N16X - L3[I] M5 R3 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  1] STATEMENT: 1500 invalid mappings (1457 fanout, 43 capacity) found since the last valid mapping, terminating search.
# [  5] Utilization = 1.00 | pJ/Compute =   31.948 | L5[WIO] P2 M50 S3 C100 - L4[O] M2 N16X - L3[IO] R3 M5 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  5] Utilization = 1.00 | pJ/Compute =   31.670 | L5[WIO] P2 M50 S3 C100 - L4[O] M2 N16X - L3[I] M5 R3 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  5] STATEMENT: 1500 invalid mappings (1450 fanout, 50 capacity) found since the last valid mapping, terminating search.
# Summary stats for best mapping found by mapper:
#   Utilization = 1.00 | pJ/Compute =   31.670
# 456.04 14400000 900000
# HERE: designs/system_manual/arch/system_arch_1x16.yaml designs/system_manual/arch/components _layers/layer_shape_3.yaml _layers/map_3.yaml designs/system_auto/mapper/mapper.yaml
# input file: tmp.yaml
#   _______                __
#  /_  __(_)___ ___  ___  / /___  ____  ____
#   / / / / __ `__ \/ _ \/ / __ \/ __ \/ __ \
#  / / / / / / / / /  __/ / /_/ / /_/ / /_/ /
# /_/ /_/_/ /_/ /_/\___/_/\____/\____/ .___/
#                                   /_/
#
# Problem configuration complete.
# Warning: neither block size nor cluster size specified, set according to specified storage width: block size: 1  cluster-size: 1
# Warning: neither block size nor cluster size specified, set according to specified storage width: block size: 1  cluster-size: 1
# Warning: neither block size nor cluster size specified, set according to specified storage width: block size: 1  cluster-size: 1
# Warning: neither block size nor cluster size specified, set according to specified storage width: block size: 1  cluster-size: 1
# Warning: neither block size nor cluster size specified, set according to specified storage width: block size: 1  cluster-size: 1
# execute:/usr/local/bin/accelergy tmp.yaml --oprefix timeloop-mapper. -o ./ > timeloop-mapper.accelergy.log 2>&1
# Generate Accelergy ERT (energy reference table) to replace internal energy model.
# Generate Accelergy ART (area reference table) to replace internal area model.
# Architecture configuration complete.
# Sparse optimization configuration complete.
# Using threads = 8
# Mapper configuration complete.
# Initializing Index Factorization subspace.
#   Factorization options along problem dimension C = 1
#   Factorization options along problem dimension M = 2352
#   Factorization options along problem dimension R = 7
#   Factorization options along problem dimension S = 1
#   Factorization options along problem dimension N = 1
#   Factorization options along problem dimension P = 1
#   Factorization options along problem dimension Q = 1
# Mapspace Dimension [IndexFactorization] Size: 16464
# Mapspace Dimension [LoopPermutation] Size: 3252016064102400000
# Mapspace Dimension [Spatial] Size: 8
# Mapspace Dimension [DatatypeBypass] Size: 64
# Mapspace split! Per-split Mapping Dimension [IndexFactorization] Size: 2058 Residue: 0
# Mapspace construction complete.
# Search configuration complete.
# WARNING: no optimization metric(s) specified, using edp as default.
# WARNING: Interpreting 0 to mean full problem dimension instead of residue.
# [  2] Utilization = 1.00 | pJ/Compute =  285.936 | L5[WIO] R3 M50 C500 - L4[] M5 N16X - L3[] M2 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  2] Utilization = 1.00 | pJ/Compute =   33.406 | L5[WIO] R3 M50 C500 - L4[O] M5 N16X - L3[] M2 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  4] Utilization = 1.00 | pJ/Compute =  285.936 | L5[WIO] R3 M50 C500 - L4[] M10 N16X - L3[] Q1 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  7] Utilization = 1.00 | pJ/Compute =  275.618 | L5[WIO] M10 C500 - L4[] Q1 N16X - L3[] R3 M50 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  4] Utilization = 1.00 | pJ/Compute =   33.406 | L5[WIO] R3 M50 C500 - L4[O] M10 N16X - L3[] Q1 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  2] Utilization = 1.00 | pJ/Compute =   33.063 | L5[WIO] M50 R3 C500 - L4[O] M5 N16X - L3[] M2 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  3] Utilization = 1.00 | pJ/Compute =  275.618 | L5[WIO] M10 C500 - L4[] R3 M50 N16X - L3[] Q1 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  7] Utilization = 1.00 | pJ/Compute =  230.697 | L5[WIO] M10 C500 - L4[] Q1 N16X - L3[] M50 R3 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  7] Utilization = 1.00 | pJ/Compute =  105.529 | L5[WIO] M10 C500 - L4[] Q1 N16X - L3[I] M50 R3 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  0] Utilization = 1.00 | pJ/Compute =  298.834 | L5[WIO] C500 - L4[] M100 N16X - L3[] R3 M5 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  0] Utilization = 1.00 | pJ/Compute =  273.544 | L5[WIO] C500 - L4[] M100 N16X - L3[I] R3 M5 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  0] Utilization = 1.00 | pJ/Compute =  128.789 | L5[WIO] C500 - L4[] M100 N16X - L3[O] R3 M5 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  0] Utilization = 1.00 | pJ/Compute =  103.498 | L5[WIO] C500 - L4[] M100 N16X - L3[IO] R3 M5 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  0] Utilization = 1.00 | pJ/Compute =  103.220 | L5[WIO] C500 - L4[] M100 N16X - L3[I] M5 R3 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  7] Utilization = 1.00 | pJ/Compute =  103.220 | L5[WIO] C500 M10 - L4[] Q1 N16X - L3[I] M50 R3 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  3] Utilization = 1.00 | pJ/Compute =  230.697 | L5[WIO] M10 C500 - L4[] M50 R3 N16X - L3[] Q1 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  3] Utilization = 1.00 | pJ/Compute =  106.633 | L5[WIO] M10 C500 - L4[I] M50 R3 N16X - L3[] Q1 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  0] Utilization = 1.00 | pJ/Compute =   49.986 | L5[WIO] M125 C500 - L4[] Q1 N16X - L3[O] R3 M4 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  1] Utilization = 1.00 | pJ/Compute =  275.618 | L5[WIO] M10 C500 - L4[] R3 M10 N16X - L3[] M5 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  3] Utilization = 1.00 | pJ/Compute =  104.300 | L5[WIO] C500 M10 - L4[I] M50 R3 N16X - L3[] Q1 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  4] Utilization = 1.00 | pJ/Compute =   33.063 | L5[WIO] M50 R3 C500 - L4[O] M10 N16X - L3[] Q1 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  6] Utilization = 1.00 | pJ/Compute =  273.555 | L5[WIO] R3 M2 C500 - L4[] M50 N16X - L3[] M5 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  1] Utilization = 1.00 | pJ/Compute =  128.789 | L5[WIO] M10 C500 - L4[] M10 R3 N16X - L3[O] M5 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  1] Utilization = 1.00 | pJ/Compute =  106.050 | L5[WIO] M10 C500 - L4[I] M10 R3 N16X - L3[O] M5 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  6] Utilization = 1.00 | pJ/Compute =  273.297 | L5[WIO] R3 C500 M2 - L4[] M50 N16X - L3[] M5 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  1] Utilization = 1.00 | pJ/Compute =  103.717 | L5[WIO] C500 M10 - L4[I] M10 R3 N16X - L3[O] M5 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  3] Utilization = 1.00 | pJ/Compute =   52.753 | L5[WIO] R3 M125 C500 - L4[O] M4 N16X - L3[] Q1 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  5] Utilization = 1.00 | pJ/Compute =  278.198 | L5[WIO] M2 C500 - L4[] M10 N16X - L3[] R3 M25 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  5] Utilization = 1.00 | pJ/Compute =  273.602 | L5[WIO] M2 C500 - L4[] M10 N16X - L3[I] R3 M25 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  5] Utilization = 1.00 | pJ/Compute =  108.153 | L5[WIO] M2 C500 - L4[] M10 N16X - L3[O] R3 M25 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  5] Utilization = 1.00 | pJ/Compute =  103.605 | L5[WIO] M2 C500 - L4[I] M10 N16X - L3[O] R3 M25 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  5] Utilization = 1.00 | pJ/Compute =  103.477 | L5[WIO] M2 C500 - L4[] M10 N16X - L3[I] M25 R3 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  5] Utilization = 1.00 | pJ/Compute =  103.346 | L5[WIO] C500 M2 - L4[I] M10 N16X - L3[O] R3 M25 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  5] Utilization = 1.00 | pJ/Compute =  103.220 | L5[WIO] C500 M2 - L4[] M10 N16X - L3[I] M25 R3 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  3] Utilization = 1.00 | pJ/Compute =   52.409 | L5[WIO] M125 R3 C500 - L4[O] M4 N16X - L3[] Q1 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  0] Utilization = 1.00 | pJ/Compute =   43.537 | L5[WIO] M100 C500 - L4[] Q1 N16X - L3[O] R3 M5 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  1] Utilization = 1.00 | pJ/Compute =  103.220 | L5[WIO] C500 M5 - L4[] M2 N16X - L3[I] M50 R3 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  5] Utilization = 1.00 | pJ/Compute =   26.614 | L5[WIO] M25 C500 - L4[O] R3 M10 N16X - L3[] M2 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  1] Utilization = 1.00 | pJ/Compute =   52.753 | L5[WIO] R3 M125 C500 - L4[O] M2 N16X - L3[] M2 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  5] Utilization = 1.00 | pJ/Compute =   26.456 | L5[WIO] M25 C500 - L4[IO] M10 R3 N16X - L3[O] M2 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  1] Utilization = 1.00 | pJ/Compute =   52.409 | L5[WIO] M125 R3 C500 - L4[O] M2 N16X - L3[] M2 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  6] Utilization = 1.00 | pJ/Compute =   23.243 | L5[WIO] R3 M20 C500 - L4[] Q1 N16X - L3[O] M25 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  0] Utilization = 1.00 | pJ/Compute =   30.640 | L5[WIO] M50 C500 - L4[] Q1 N16X - L3[O] R3 M10 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  4] Utilization = 1.00 | pJ/Compute =   26.958 | L5[WIO] R3 M25 C500 - L4[O] M5 N16X - L3[] M4 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  6] Utilization = 1.00 | pJ/Compute =   22.901 | L5[WIO] M20 R3 C500 - L4[] Q1 N16X - L3[O] M25 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  4] Utilization = 1.00 | pJ/Compute =   26.614 | L5[WIO] M25 R3 C500 - L4[O] M5 N16X - L3[] M4 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  3] STATEMENT: 1500 invalid mappings (1373 fanout, 127 capacity) found since the last valid mapping, terminating search.
# [  7] Utilization = 1.00 | pJ/Compute =   26.614 | L5[WIO] M25 C500 - L4[O] R3 M20 N16X - L3[] Q1 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  2] Utilization = 1.00 | pJ/Compute =   32.264 | L5[WIO] M50 C500 - L4[O] M5 N16X - L3[IO] R3 M2 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  7] Utilization = 1.00 | pJ/Compute =   26.344 | L5[WIO] M25 C500 - L4[IO] M20 R3 N16X - L3[] Q1 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  0] STATEMENT: 1500 invalid mappings (1354 fanout, 146 capacity) found since the last valid mapping, terminating search.
# [  2] Utilization = 1.00 | pJ/Compute =   31.613 | L5[WIO] M50 C500 - L4[O] M5 N16X - L3[I] M2 R3 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  1] Utilization = 1.00 | pJ/Compute =   51.504 | L5[WIO] M125 C500 - L4[O] M2 N16X - L3[IO] R3 M2 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  1] Utilization = 1.00 | pJ/Compute =   50.853 | L5[WIO] M125 C500 - L4[O] M2 N16X - L3[I] M2 R3 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  5] STATEMENT: 1500 invalid mappings (1345 fanout, 155 capacity) found since the last valid mapping, terminating search.
# [  7] Utilization = 1.00 | pJ/Compute =   25.324 | L5[WIO] M20 C500 - L4[O] R3 M5 N16X - L3[] M5 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  7] Utilization = 1.00 | pJ/Compute =   24.465 | L5[WIO] M20 C500 - L4[IO] M5 R3 N16X - L3[O] M5 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  1] Utilization = 1.00 | pJ/Compute =   24.191 | L5[WIO] M25 C500 - L4[] Q1 N16X - L3[O] R3 M20 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  4] Utilization = 1.00 | pJ/Compute =   25.877 | L5[WIO] M25 C500 - L4[IO] M5 R3 N16X - L3[O] M4 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  1] Utilization = 1.00 | pJ/Compute =   23.917 | L5[WIO] M20 C500 - L4[O] M25 N16X - L3[I] R3 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  4] Utilization = 1.00 | pJ/Compute =   25.529 | L5[WIO] M25 C500 - L4[IO] M2 R3 N16X - L3[O] M10 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  4] Utilization = 1.00 | pJ/Compute =   25.354 | L5[WIO] M25 C500 - L4[O] M2 N16X - L3[IO] R3 M10 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  4] Utilization = 1.00 | pJ/Compute =   25.200 | L5[WIO] M25 C500 - L4[O] M2 N16X - L3[I] M10 R3 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  6] STATEMENT: 1500 invalid mappings (1350 fanout, 150 capacity) found since the last valid mapping, terminating search.
# [  7] Utilization = 1.00 | pJ/Compute =   24.195 | L5[WIO] M20 C500 - L4[O] M5 N16X - L3[IO] R3 M5 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  7] Utilization = 1.00 | pJ/Compute =   23.917 | L5[WIO] M20 C500 - L4[O] M5 N16X - L3[I] M5 R3 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  7] STATEMENT: 1500 invalid mappings (1333 fanout, 167 capacity) found since the last valid mapping, terminating search.
# [  2] STATEMENT: 800 suboptimal mappings found since the last upgrade, terminating search.
# [  1] STATEMENT: 800 suboptimal mappings found since the last upgrade, terminating search.
# [  4] STATEMENT: 800 suboptimal mappings found since the last upgrade, terminating search.
# Summary stats for best mapping found by mapper:
#   Utilization = 1.00 | pJ/Compute =   22.901
# 274.82 12000000 750000
# HERE: designs/system_manual/arch/system_arch_1x16.yaml designs/system_manual/arch/components _layers/layer_shape_4.yaml _layers/map_4.yaml designs/system_auto/mapper/mapper.yaml
# input file: tmp.yaml
#   _______                __
#  /_  __(_)___ ___  ___  / /___  ____  ____
#   / / / / __ `__ \/ _ \/ / __ \/ __ \/ __ \
#  / / / / / / / / /  __/ / /_/ / /_/ / /_/ /
# /_/ /_/_/ /_/ /_/\___/_/\____/\____/ .___/
#                                   /_/
#
# Problem configuration complete.
# Warning: neither block size nor cluster size specified, set according to specified storage width: block size: 1  cluster-size: 1
# Warning: neither block size nor cluster size specified, set according to specified storage width: block size: 1  cluster-size: 1
# Warning: neither block size nor cluster size specified, set according to specified storage width: block size: 1  cluster-size: 1
# Warning: neither block size nor cluster size specified, set according to specified storage width: block size: 1  cluster-size: 1
# Warning: neither block size nor cluster size specified, set according to specified storage width: block size: 1  cluster-size: 1
# execute:/usr/local/bin/accelergy tmp.yaml --oprefix timeloop-mapper. -o ./ > timeloop-mapper.accelergy.log 2>&1
# Generate Accelergy ERT (energy reference table) to replace internal energy model.
# Generate Accelergy ART (area reference table) to replace internal area model.
# Architecture configuration complete.
# Sparse optimization configuration complete.
# Using threads = 8
# Mapper configuration complete.
# Initializing Index Factorization subspace.
#   Factorization options along problem dimension C = 1
#   Factorization options along problem dimension M = 12936
#   Factorization options along problem dimension R = 7
#   Factorization options along problem dimension S = 1
#   Factorization options along problem dimension N = 1
#   Factorization options along problem dimension P = 1
#   Factorization options along problem dimension Q = 1
# Mapspace Dimension [IndexFactorization] Size: 90552
# Mapspace Dimension [LoopPermutation] Size: 3252016064102400000
# Mapspace Dimension [Spatial] Size: 8
# Mapspace Dimension [DatatypeBypass] Size: 64
# Mapspace split! Per-split Mapping Dimension [IndexFactorization] Size: 11319 Residue: 0
# Mapspace construction complete.
# Search configuration complete.
# WARNING: no optimization metric(s) specified, using edp as default.
# WARNING: Interpreting 0 to mean full problem dimension instead of residue.
# [  1] Utilization = 1.00 | pJ/Compute =  274.651 | L5[WIO] R3 M10 C500 - L4[] M4 N16X - L3[] M20 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  5] Utilization = 1.00 | pJ/Compute =  285.936 | L5[WIO] M80 C500 - L4[] R3 M2 N16X - L3[] M5 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  3] Utilization = 1.00 | pJ/Compute =  274.651 | L5[WIO] M10 C500 - L4[] R3 M16 N16X - L3[] M5 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  6] Utilization = 1.00 | pJ/Compute =  337.526 | L5[WIO] M400 C500 - L4[] Q1 N16X - L3[] R3 M2 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  1] Utilization = 1.00 | pJ/Compute =  273.200 | L5[WIO] R3 C500 M10 - L4[] M4 N16X - L3[] M20 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  5] Utilization = 1.00 | pJ/Compute =   33.063 | L5[WIO] M80 C500 - L4[O] R3 M2 N16X - L3[] M5 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  6] Utilization = 1.00 | pJ/Compute =   82.230 | L5[WIO] M400 C500 - L4[] Q1 N16X - L3[O] R3 M2 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  3] Utilization = 1.00 | pJ/Compute =  128.789 | L5[WIO] M10 C500 - L4[] M16 R3 N16X - L3[O] M5 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  3] Utilization = 1.00 | pJ/Compute =  105.078 | L5[WIO] M10 C500 - L4[I] M16 R3 N16X - L3[O] M5 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  2] STATEMENT: 1500 invalid mappings (1409 fanout, 91 capacity) found since the last valid mapping, terminating search.
# [  0] STATEMENT: 1500 invalid mappings (1406 fanout, 94 capacity) found since the last valid mapping, terminating search.
# [  3] Utilization = 1.00 | pJ/Compute =  103.619 | L5[WIO] C500 M10 - L4[I] M16 R3 N16X - L3[O] M5 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  6] Utilization = 1.00 | pJ/Compute =   82.112 | L5[WIO] M400 C500 - L4[] Q1 N16X - L3[IO] M2 R3 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  5] Utilization = 1.00 | pJ/Compute =   32.241 | L5[WIO] M80 C500 - L4[IO] M2 R3 N16X - L3[O] M5 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  4] STATEMENT: 1500 invalid mappings (1407 fanout, 93 capacity) found since the last valid mapping, terminating search.
# [  7] STATEMENT: 1500 invalid mappings (1408 fanout, 92 capacity) found since the last valid mapping, terminating search.
# [  3] Utilization = 1.00 | pJ/Compute =  103.605 | L5[WIO] M4 C500 - L4[] M4 N16X - L3[I] M50 R3 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  3] Utilization = 1.00 | pJ/Compute =  103.124 | L5[WIO] C500 M4 - L4[] M4 N16X - L3[I] M50 R3 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  1] STATEMENT: 1500 invalid mappings (1398 fanout, 102 capacity) found since the last valid mapping, terminating search.
# [  5] STATEMENT: 1500 invalid mappings (1401 fanout, 99 capacity) found since the last valid mapping, terminating search.
# [  6] STATEMENT: 1500 invalid mappings (1391 fanout, 109 capacity) found since the last valid mapping, terminating search.
# [  3] STATEMENT: 1500 invalid mappings (1392 fanout, 108 capacity) found since the last valid mapping, terminating search.
# Summary stats for best mapping found by mapper:
#   Utilization = 1.00 | pJ/Compute =   32.241
# 619.03 19200000 1200000
# HERE: designs/system_manual/arch/system_arch_1x16.yaml designs/system_manual/arch/components _layers/layer_shape_5.yaml _layers/map_5.yaml designs/system_auto/mapper/mapper.yaml
# input file: tmp.yaml
#   _______                __
#  /_  __(_)___ ___  ___  / /___  ____  ____
#   / / / / __ `__ \/ _ \/ / __ \/ __ \/ __ \
#  / / / / / / / / /  __/ / /_/ / /_/ / /_/ /
# /_/ /_/_/ /_/ /_/\___/_/\____/\____/ .___/
#                                   /_/
#
# Problem configuration complete.
# Warning: neither block size nor cluster size specified, set according to specified storage width: block size: 1  cluster-size: 1
# Warning: neither block size nor cluster size specified, set according to specified storage width: block size: 1  cluster-size: 1
# Warning: neither block size nor cluster size specified, set according to specified storage width: block size: 1  cluster-size: 1
# Warning: neither block size nor cluster size specified, set according to specified storage width: block size: 1  cluster-size: 1
# Warning: neither block size nor cluster size specified, set according to specified storage width: block size: 1  cluster-size: 1
# execute:/usr/local/bin/accelergy tmp.yaml --oprefix timeloop-mapper. -o ./ > timeloop-mapper.accelergy.log 2>&1
# Generate Accelergy ERT (energy reference table) to replace internal energy model.
# Generate Accelergy ART (area reference table) to replace internal area model.
# Architecture configuration complete.
# Sparse optimization configuration complete.
# Using threads = 8
# Mapper configuration complete.
# Initializing Index Factorization subspace.
#   Factorization options along problem dimension C = 1
#   Factorization options along problem dimension M = 7056
#   Factorization options along problem dimension R = 7
#   Factorization options along problem dimension S = 1
#   Factorization options along problem dimension N = 1
#   Factorization options along problem dimension P = 1
#   Factorization options along problem dimension Q = 1
# Mapspace Dimension [IndexFactorization] Size: 49392
# Mapspace Dimension [LoopPermutation] Size: 3252016064102400000
# Mapspace Dimension [Spatial] Size: 8
# Mapspace Dimension [DatatypeBypass] Size: 64
# Mapspace split! Per-split Mapping Dimension [IndexFactorization] Size: 6174 Residue: 0
# Mapspace construction complete.
# Search configuration complete.
# WARNING: no optimization metric(s) specified, using edp as default.
# WARNING: Interpreting 0 to mean full problem dimension instead of residue.
# [  4] Utilization = 1.00 | pJ/Compute =  279.493 | L5[WIO] R2 M50 C800 - L4[] Q1 N16X - L3[] M20 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  2] Utilization = 1.00 | pJ/Compute =  274.334 | L5[WIO] R2 M10 C800 - L4[] M50 N16X - L3[] M2 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  3] Utilization = 1.00 | pJ/Compute =  273.302 | L5[WIO] M2 C800 - L4[] Q1 N16X - L3[] R2 M500 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  4] Utilization = 1.00 | pJ/Compute =   24.346 | L5[WIO] R2 M50 C800 - L4[] Q1 N16X - L3[O] M20 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  3] Utilization = 1.00 | pJ/Compute =  146.055 | L5[WIO] M2 C800 - L4[] Q1 N16X - L3[I] M500 R2 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  7] Utilization = 1.00 | pJ/Compute =  273.560 | L5[WIO] M4 C800 - L4[] R2 N16X - L3[] M250 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  7] Utilization = 1.00 | pJ/Compute =  273.183 | L5[WIO] C800 M4 - L4[I] R2 N16X - L3[] M250 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  1] Utilization = 1.00 | pJ/Compute =  305.288 | L5[WIO] M250 C800 - L4[] R2 M2 N16X - L3[] M2 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  7] Utilization = 1.00 | pJ/Compute =  147.081 | L5[WIO] M10 C800 - L4[] M2 N16X - L3[I] M50 R2 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  3] Utilization = 1.00 | pJ/Compute =  145.926 | L5[WIO] C800 M2 - L4[] Q1 N16X - L3[I] M500 R2 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  1] Utilization = 1.00 | pJ/Compute =   52.404 | L5[WIO] M250 C800 - L4[O] R2 M2 N16X - L3[] M2 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  7] Utilization = 1.00 | pJ/Compute =  145.926 | L5[WIO] C800 M10 - L4[] M2 N16X - L3[I] M50 R2 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  0] STATEMENT: 1500 invalid mappings (1396 fanout, 104 capacity) found since the last valid mapping, terminating search.
# [  6] Utilization = 1.00 | pJ/Compute =  273.560 | L5[WIO] M4 C800 - L4[] R2 M5 N16X - L3[] M50 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  4] Utilization = 1.00 | pJ/Compute =   24.186 | L5[WIO] M50 R2 C800 - L4[] Q1 N16X - L3[O] M20 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  6] Utilization = 1.00 | pJ/Compute =  273.183 | L5[WIO] C800 M4 - L4[I] R2 M5 N16X - L3[] M50 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  5] STATEMENT: 1500 invalid mappings (1387 fanout, 113 capacity) found since the last valid mapping, terminating search.
# [  2] Utilization = 1.00 | pJ/Compute =  273.173 | L5[WIO] R2 C800 M10 - L4[] M50 N16X - L3[] M2 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  6] Utilization = 1.00 | pJ/Compute =  177.954 | L5[WIO] M5 C800 - L4[] M50 N16X - L3[O] R2 M4 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  6] Utilization = 1.00 | pJ/Compute =  146.662 | L5[WIO] M5 C800 - L4[] M50 N16X - L3[IO] R2 M4 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  3] Utilization = 1.00 | pJ/Compute =   52.404 | L5[WIO] M250 C800 - L4[O] R2 M4 N16X - L3[] Q1 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  6] Utilization = 1.00 | pJ/Compute =  146.439 | L5[WIO] M5 C800 - L4[] M50 N16X - L3[I] M4 R2 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  6] Utilization = 1.00 | pJ/Compute =  146.149 | L5[WIO] C800 M5 - L4[] M50 N16X - L3[IO] R2 M4 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  6] Utilization = 1.00 | pJ/Compute =  145.926 | L5[WIO] C800 M5 - L4[] M50 N16X - L3[I] M4 R2 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  7] Utilization = 1.00 | pJ/Compute =   43.532 | L5[WIO] M200 C800 - L4[] Q1 N16X - L3[O] R2 M5 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  2] STATEMENT: 1500 invalid mappings (1389 fanout, 111 capacity) found since the last valid mapping, terminating search.
# [  6] STATEMENT: 1500 invalid mappings (1410 fanout, 90 capacity) found since the last valid mapping, terminating search.
# [  1] STATEMENT: 1500 invalid mappings (1392 fanout, 108 capacity) found since the last valid mapping, terminating search.
# [  7] STATEMENT: 1500 invalid mappings (1379 fanout, 121 capacity) found since the last valid mapping, terminating search.
# [  4] Utilization = 1.00 | pJ/Compute =   22.896 | L5[WIO] M40 C800 - L4[] R2 N16X - L3[O] M25 - L2[W] Q1 - L1[I] Q1 - L0[O] Q1
# [  3] STATEMENT: 1500 invalid mappings (1389 fanout, 111 capacity) found since the last valid mapping, terminating search.
# [  4] STATEMENT: 1500 invalid mappings (1369 fanout, 131 capacity) found since the last valid mapping, terminating search.
# Summary stats for best mapping found by mapper:
#   Utilization = 1.00 | pJ/Compute =   22.896
# 586.14 25600000 1600000
# HERE: designs/system_manual/arch/system_arch_1x16.yaml designs/system_manual/arch/components _layers/layer_shape_6.yaml _layers/map_6.yaml designs/system_auto/mapper/mapper.yaml
# input file: tmp.yaml
#   _______                __
#  /_  __(_)___ ___  ___  / /___  ____  ____
#   / / / / __ `__ \/ _ \/ / __ \/ __ \/ __ \
#  / / / / / / / / /  __/ / /_/ / /_/ / /_/ /
# /_/ /_/_/ /_/ /_/\___/_/\____/\____/ .___/
#                                   /_/
#
# Problem configuration complete.
# Warning: neither block size nor cluster size specified, set according to specified storage width: block size: 1  cluster-size: 1
# Warning: neither block size nor cluster size specified, set according to specified storage width: block size: 1  cluster-size: 1
# Warning: neither block size nor cluster size specified, set according to specified storage width: block size: 1  cluster-size: 1
# Warning: neither block size nor cluster size specified, set according to specified storage width: block size: 1  cluster-size: 1
# Warning: neither block size nor cluster size specified, set according to specified storage width: block size: 1  cluster-size: 1
# execute:/usr/local/bin/accelergy tmp.yaml --oprefix timeloop-mapper. -o ./ > timeloop-mapper.accelergy.log 2>&1
# Generate Accelergy ERT (energy reference table) to replace internal energy model.
# Generate Accelergy ART (area reference table) to replace internal area model.
# Architecture configuration complete.
# Sparse optimization configuration complete.
# Using threads = 8
# Mapper configuration complete.
# Initializing Index Factorization subspace.
#   Factorization options along problem dimension N = 1
#   Factorization options along problem dimension I = 7056
#   Factorization options along problem dimension O = 210
# Mapspace Dimension [IndexFactorization] Size: 1481760
# Mapspace Dimension [LoopPermutation] Size: 7776
# Mapspace Dimension [Spatial] Size: 4
# Mapspace Dimension [DatatypeBypass] Size: 64
# Mapspace split! Per-split Mapping Dimension [IndexFactorization] Size: 185220 Residue: 0
# Mapspace construction complete.
# Search configuration complete.
# WARNING: no optimization metric(s) specified, using edp as default.
# [  6] STATEMENT: 1500 invalid mappings (1439 fanout, 61 capacity) found since the last valid mapping, terminating search.
# [  0] Utilization = 1.00 | pJ/Compute =  196.391 | L5[WIO] O2 I8 - L4[] O4 I25 N16X - L3[] O2 I5 - L2[W] O1 - L1[I] O1 - L0[O] O1
# [  0] Utilization = 1.00 | pJ/Compute =  132.790 | L5[WIO] O2 I8 - L4[] O4 I25 N16X - L3[I] O2 I5 - L2[W] O1 - L1[I] O1 - L0[O] O1
# [  0] Utilization = 1.00 | pJ/Compute =   83.747 | L5[WIO] O2 I8 - L4[] O4 I25 N16X - L3[IO] O2 I5 - L2[W] O1 - L1[I] O1 - L0[O] O1
# [  3] STATEMENT: 1500 invalid mappings (1432 fanout, 68 capacity) found since the last valid mapping, terminating search.
# [  0] Utilization = 1.00 | pJ/Compute =   82.438 | L5[WIO] O2 I8 - L4[O] O4 I25 N16X - L3[I] O2 I5 - L2[W] O1 - L1[I] O1 - L0[O] O1
# [  1] STATEMENT: 1500 invalid mappings (1430 fanout, 70 capacity) found since the last valid mapping, terminating search.
# [  0] Utilization = 1.00 | pJ/Compute =   81.979 | L5[WIO] O2 I8 - L4[O] O4 I25 N16X - L3[IO] O2 I5 - L2[W] O1 - L1[I] O1 - L0[O] O1
# [  5] Utilization = 1.00 | pJ/Compute =  209.240 | L5[WIO] O8 I10 - L4[] I25 N16X - L3[] O2 I4 - L2[W] O1 - L1[I] O1 - L0[O] O1
# [  5] Utilization = 1.00 | pJ/Compute =  145.639 | L5[WIO] O8 I10 - L4[] I25 N16X - L3[I] O2 I4 - L2[W] O1 - L1[I] O1 - L0[O] O1
# [  5] Utilization = 1.00 | pJ/Compute =  145.629 | L5[WIO] O8 I10 - L4[] I25 N16X - L3[O] O2 I4 - L2[W] O1 - L1[I] O1 - L0[O] O1
# [  5] Utilization = 1.00 | pJ/Compute =   82.028 | L5[WIO] O8 I10 - L4[] I25 N16X - L3[IO] O2 I4 - L2[W] O1 - L1[I] O1 - L0[O] O1
# [  4] STATEMENT: 1500 invalid mappings (1436 fanout, 64 capacity) found since the last valid mapping, terminating search.
# [  2] STATEMENT: 1500 invalid mappings (1436 fanout, 64 capacity) found since the last valid mapping, terminating search.
# [  0] Utilization = 1.00 | pJ/Compute =   34.338 | L5[WIO] O2 I8 - L4[O] I25 O4 N16X - L3[I] O2 I5 - L2[W] O1 - L1[I] O1 - L0[O] O1
# [  7] STATEMENT: 1500 invalid mappings (1434 fanout, 66 capacity) found since the last valid mapping, terminating search.
# [  5] STATEMENT: 1500 invalid mappings (1447 fanout, 53 capacity) found since the last valid mapping, terminating search.
# [  0] STATEMENT: 1500 invalid mappings (1446 fanout, 54 capacity) found since the last valid mapping, terminating search.
# Summary stats for best mapping found by mapper:
#   Utilization = 1.00 | pJ/Compute =   34.338
# 8.79 256000 16000
# layer types: ['conv2d', 'conv2d', 'conv2d', 'conv2d', 'conv2d', 'conv2d', 'linear']
# energy: 2091.0699999999997 (layerwise: [130.56, 15.69, 456.04, 274.82, 619.03, 586.14, 8.79])
# mac: 77216000 (layerwise: [5184000, 576000, 14400000, 12000000, 19200000, 25600000, 256000])
# param: 4058000 (layerwise: [36000, 6000, 450000, 750000, 1200000, 1600000, 16000])
# cycle: 4826000 (layerwise: [324000, 36000, 900000, 750000, 1200000, 1600000, 16000])

# %% [markdown]
# # Plotting Energy-Acc Trade-off

# %%
# Define the data in a dictionary
three_dim_data = {'Total Energy [uJ]': [92.83, 98.85, 244.5, 334.74, 569.12, 1662.81, 2081.05, 2420.25, 2553.41, 3400.11],
        'Accuracy': [88.34, 94.98, 95.27, 96.63, 96.93, 97.61, 97.71, 97.76, 97.85, 98.29],
        'MAC': [2110912, 2387712, 8458800, 11990400, 21399120, 62802640, 76564960, 98673280, 104952480, 141696480],
        'Param': [1102, 2202, 6840, 8265, 10425, 28375, 46120, 71140, 92340, 120840],
        'Cycle': [131932, 149232, 871600, 1018750, 1820500, 5499790, 7333940, 6167080, 6559530, 8856030],
       }

two_dim_data = {'Total Energy [uJ]': [145.17, 148.68, 152.59, 161.64, 179.02, 254.81, 643.48, 759.58, 1715.26],
        'Accuracy': [76.48, 82.19, 84.89, 83.90, 85.18, 93.61, 93.30, 95.90, 96.50],
        'MAC': [5666560, 5920000, 6086400, 6470400.00, 7180800.00, 9977600.00, 21760000.00, 26176000.00, 65235200.00],
        'Param': [53860, 67000, 77400, 96900, 136800, 311600, 1048000, 1306000, 3693200],
        'Cycle': [354160, 370000, 380400, 404400, 448800, 623600, 1360000, 1636000, 4077200],
       }

# Create a pandas dataframe from the data
three_df = pd.DataFrame(three_dim_data)
two_df = pd.DataFrame(two_dim_data)

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figsize=(15, 10)

# Add a new column to each DataFrame to identify their source
three_df['Model'] = '3D CNN'
two_df['Model'] = '2D CNN'

# Concatenate the DataFrames
combined_df = pd.concat([three_df, two_df], ignore_index=True)

sns.set_style("ticks")
scatterplot = sns.scatterplot(data=combined_df, x='Total Energy [uJ]', y='Accuracy', hue='Model', palette='magma')
scatterplot.set_xlabel('Total Energy [uJ]')
scatterplot.set_ylabel('Accuracy')
plt.savefig('./figures/energy-acc.png', dpi=300)
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figsize=(15, 10)

# Add a new column to each DataFrame to identify their source
three_df['Model'] = '3D CNN'
two_df['Model'] = '2D CNN'

# Concatenate the DataFrames
combined_df = pd.concat([three_df, two_df], ignore_index=True)

sns.set_style("ticks")
scatterplot = sns.scatterplot(data=combined_df, x='MAC', y='Accuracy', hue='Model', palette='magma')
scatterplot.set_xlabel('MAC')
scatterplot.set_ylabel('Accuracy')
plt.savefig('./figures/mac-acc.png', dpi=300)

plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figsize=(15, 10)

# Add a new column to each DataFrame to identify their source
three_df['Model'] = '3D CNN'
two_df['Model'] = '2D CNN'

# Concatenate the DataFrames
combined_df = pd.concat([three_df, two_df], ignore_index=True)

sns.set_style("ticks")
scatterplot = sns.scatterplot(data=combined_df, x='Cycle', y='Accuracy', hue='Model', palette='magma')
scatterplot.set_xlabel('Cycle')
scatterplot.set_ylabel('Accuracy')
plt.savefig('./figures/cycle-acc.png', dpi=300)

plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

plt.figsize=(15, 10)

# Add a new column to each DataFrame to identify their source
three_df['Model'] = '3D CNN'
two_df['Model'] = '2D CNN'

# Concatenate the DataFrames
combined_df = pd.concat([three_df, two_df], ignore_index=True)

sns.set_style("ticks")
scatterplot = sns.scatterplot(data=combined_df, x='Param', y='Accuracy', hue='Model', palette='magma')
scatterplot.set_xlabel('# Parameters')
scatterplot.set_ylabel('Accuracy')
plt.savefig('./figures/param-acc.png', dpi=300)

plt.show()
